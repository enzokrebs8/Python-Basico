# %% [markdown]
# ## Criando uma base numa lista e transformando num DataFrame

# %%
#Importando uma biblioteca de Processamento de Linguaguem natural
import nltk

# %%
#base criada na mão, com frases aleatórias
base = [('não precisei pagar o ingresso','alegria'),
('se eu ajeitar tudo fica bem','alegria'),
('minha fortuna ultrapassa a sua','alegria'),
('sou muito afortunado','alegria'),
('e benefico para todos esta nova medida','alegria'),
('ficou lindo','alegria'),
('achei esse sapato muito simpático','alegria'),
('estou ansiosa pela sua chegada','alegria'),
('congratulações pelo seu aniversário','alegria'),
('delicadamente ele a colocou para dormir','alegria'),
('a musica e linda','alegria'),
('sem musica eu não vivo','alegria'),
('conclui uma tarefa muito difícil','alegria'),
('conclui minha graduação','alegria'),
('estou muito contente com tudo','alegria'),
('eu confio em você','alegria'),
('e um prazer conhecê-lo','alegria'),
('o coleguismo de vocês e animador','alegria'),
('estou aproveitando as ferias','alegria'),
('vamos aproveitar as ferias','alegria'),
('e muito divertido este jogo','alegria'),
('vamos ter muita diversão','alegria'),
('não achei que me divertiria tanto assim','alegria'),
('vou consentir o orçamento ao cliente','alegria'),
('com o consentimento dos meus pais podemos nos casar','alegria'),
('eu adorei este perfume','alegria'),
('sua bondade e cativante','alegria'),
('estou despreocupada','alegria'),
('não me preocupo com o que aconteceu','alegria'),
('me sinto completamente segura','alegria'),
('estimo muito o seu trabalho','alegria'),
('somos estimados por nossa família','alegria'),
('concretizamos nossa ideia','alegria'),
('nosso ideal foi alcançado','alegria'),
('estamos muito felizes juntos','alegria'),
('estou tão animada com os preparativos para o casamento','alegria'),
('você será muito amado meu filho','alegria'),
('os apaixonados são maravilhosos','alegria'),
('agradeço imensamente o seu apoio nestes dias','alegria'),
('esta comida me parece muito atraente','alegria'),
('você me completa','alegria'),
('poderemos completar o projeto hoje!','alegria'),
('estamos namorando','alegria'),
('estou namorando este vestido a um tempo','alegria'),
('pude comprar meu celular hoje','alegria'),
('e um deleite poder compartilhar minhas vitórias','alegria'),
('ela e um boa garota','alegria'),
('estivemos em um ótimo show','alegria'),
('este trabalho e agradável','alegria'),
('gosto de ficar no seu aconchego','alegria'),
('fiz a adesão ao curso hoje','alegria'),
('eu sou admirada por muitos','alegria'),
('adoro como você e','alegria'),
('adoro seu cabelo macio','alegria'),
('adoro a cor dos seus olhos','alegria'),
('somo tão amáveis um com o outro','alegria'),
('sinto uma grande afeição por ele','alegria'),
('quero agradar meus filhos','alegria'),
('me sinto completamente amado','alegria'),
('eu amo você','alegria'),
('que grande alivio','alegria'),
('a dor esta amenizando finalmente','alegria'),
('acho que me apaixonei','alegria'),
('amar e maravilhoso','alegria'),
('estou me sentindo muito animada','alegria'),
('me sinto muito bem hoje','alegria'),
('como o luar e belo','alegria'),
('o dia esta muito bonito','alegria'),
('nossa como sou afortunado','alegria'),
('as maravilhas do mundo','alegria'),
('recebi muito carinho hoje do meus colegas','alegria'),
('estou me sentindo reconfortada hoje','alegria'),
('e muito bom estar com os amigos','alegria'),
('estou muito contente com o resultado dos testes','alegria'),
('essa pintura esta bem brilhante','alegria'),
('temos água em abundancia','alegria'),
('que roupa delicada','alegria'),
('você e um grande comediante','alegria'),
('que bondade a sua em vir aqui','alegria'),
('o amor e lindo','alegria'),
('nossa amizade vai durar para sempre','alegria'),
('estou eufórica com a noticia','alegria'),
('ele e realmente fiel a mim','alegria'),
('vou dar uma grande festa para comemorar meu aniversário','alegria'),
('graças a deus que eu enxerguei o certo','alegria'),
('essa e a melhor escolhas de todas','alegria'),
('o mais incrível e você minha bela','alegria'),
('e tão engraçado tentar explicar','alegria'),
('e emocionante estar neste lugar','alegria'),
('estou cativada pelo seu olhar','alegria'),
('estou loucamente apaixonada','alegria'),
('eu nunca tive duvidas','alegria'),
('estou rodeada pelo seu abraço','alegria'),
('eu vejo estrelas pelo caminho','alegria'),
('eu sinto o sol sempre que você esta por perto','alegria'),
('eu estou sorrindo de orelha a orelha','alegria'),
('isso vale a pena','alegria'),
('finalmente você colocou meu amor em primeiro lugar','alegria'),
('nós dançamos noite adentro','alegria'),
('seu amor e brilhante','alegria'),
('toquei muitos corações durante o meu caminho','alegria'),
('eu serei sua amiga e companheira','alegria'),
('você me traz de volta a vida','alegria'),
('você e como um sonho doce','alegria'),
('adoro este doce de frutas','alegria'),
('meu suco favorito','alegria'),
('estou agradecida pela ajuda','alegria'),
('e um enorme prazer ter você em nossa equipe','alegria'),
('trabalhar em equipe e o melhor','alegria'),
('me sinto flutuando no ar','alegria'),
('a brisa esta agradável hoje','alegria'),
('ótimo e compatível','alegria'),
('somos compatíveis um com o outro','alegria'),
('o órgão e compatível com o paciente','alegria'),
('estou contente fui aceita na faculdade','alegria'),
('fui aprovada no meu exame','alegria'),
('fui beneficiada pela minha empresa','alegria'),
('eu sou muito cativante','alegria'),
('estou contente com o apoio','alegria'),
('como este lugar e confortável','alegria'),
('e bom estar quente neste frio','alegria'),
('um elogio nunca e demais','alegria'),
('vou te chamar para comemorar','alegria'),
('e desejável a sua presença em nossa apresentação','alegria'),
('sou muito grata a você','alegria'),
('me dedico muito naquilo que faço','alegria'),
('estou completamente apaixonada ','alegria'),
('vamos agitar essa noite ','alegria'),
('você significa muito para mim','alegria'),
('vamos agir sem preconceitos e julgamentos','alegria'),
('finalmente completei a minha coleção, maravilhoso','alegria'),
('eu sou sua rainha ','alegria'),
('satisfatoriamente eu anuncio o vencedor dos jogos','alegria'),
('você me atrai facilmente ','alegria'),
('aquele rapaz e extremamente atraente','alegria'),
('sinto-me viva ','alegria'),
('sinto-me em paz ','alegria'),
('estamos tendo muito lucro','alegria'),
('muito bem esta tudo em ordem agora ','alegria'),
('podemos arrumar um emprego juntos ','alegria'),
('a arrumação esta terminada, que alívio','alegria'),
('o câncer e benigno ','alegria'),
('o amor e abundante','alegria'),
('vamos ser caridosos este natal','alegria'),
('com todo esse charme você irá atrair a todos','alegria'),
('nossa como você e charmoso querido ','alegria'),
('sou querida pelos meu amigos','alegria'),
('seja cuidadoso com os meus sentimentos','alegria'),
('estou comovido com tamanha caridade','alegria'),
('um chá quente e reconfortante','alegria'),
('que alegria ter vocês aqui ','alegria'),
('vamos aplaudir o vencedor ','alegria'),
('palmas para a aniversariante','alegria'),
('desejo a você tudo de bom','alegria'),
('hora de apreciar um bom vinho','alegria'),
('aprecio sua presença em minha escola','alegria'),
('anseio por seus próximos trabalhos','alegria'),
('maravilhoso jogo amistoso','alegria'),
('e ótimo que os ânimos tenham se apaziguado','alegria'),
('concretizei finalmente meu sonho','alegria'),
('eu imploro, não me matem!','medo'),
('tem certeza que não e perigoso?','medo'),
('não tenho certeza se e seguro','medo'),
('tenho que correr pra não me pegarem','medo'),
('socorro! ele queria roubar os meus doces!','medo'),
('esse cara está me perseguindo','medo'),
('não entro lá, e um lugar muito perigoso','medo'),
('este lugar continua assustador','medo'),
('na selva tem muitos animais perigosos','medo'),
('avancem com cautela','medo'),
('este lugar está silencioso de mais, cuidado!','medo'),
('por favor, deixe-me viver!','medo'),
('vou ficar sem mesada se tirar nota baixa','medo'),
('parece que tem olhos nos vigiando','medo'),
('eu temo que a sentença do juiz possa ser negativa','medo'),
('mas essa missão e arriscada','medo'),
('salvem-se quem puder!','medo'),
('meu plano pode ser descoberto','medo'),
('não tive culpa, juro não fui eu','medo'),
('tenho que tomar cuidado com o lobisomem','medo'),
('se eu não achar, ele vai descobrir a verdade','medo'),
('meu deus, ele desapareceu!','medo'),
('tomara que eles não me vejam daqui!','medo'),
('mantenha isso em segredo, se descobrirem estaremos ferrados','medo'),
('por favor, me soltem, eu sou inocente','medo'),
('estou ouvindo passos atrás de mim','medo'),
('eu vou pedir socorro!','medo'),
('cuidado com as curvas na estrada','medo'),
('não sei não, parece perigoso','medo'),
('estou tremendo de medo!','medo'),
('socorro, eu vou cair!','medo'),
('eu não vou ate a floresta negra, e muito perigoso','medo'),
('ouço passos na minha direção','medo'),
('acho que está arriscado de mais','medo'),
('vamos voltar, e muito perigoso','medo'),
('fuja, se não acabaremos mortos','medo'),
('receio por não me livrar desta situação','medo'),
('socorro! ele está armado!','medo'),
('ei cuidado, você vai bater no poste!','medo'),
('socorro, nós estamos afundando','medo'),
('e serio, cuidado com essa arma!','medo'),
('os tubarões estão atacando!','medo'),
('sinto arrepios quando fico sozinho no escuro','medo'),
('calma, eu não estou com o dinheiro','medo'),
('eu acho que estou sendo enganado','medo'),
('ligeiro, temos que fugir depressa','medo'),
('tem um crocodilo selvagem vindo para cá','medo'),
('se ficarmos quietos eles não vão nos achar','medo'),
('fuja! o tigre parece faminto','medo'),
('estou sem saída, preciso de um milagre','medo'),
('tire isso de mim! socorro!','medo'),
('não sei nadar, vou me afogar!','medo'),
('não tenho certeza se e seguro','medo'),
('vou apanhar se meus pais verem meu boletim','medo'),
('não consigo sair daqui!','medo'),
('se sair tão tarde, poderei ser assaltada','medo'),
('não me deixe por favor!','medo'),
('espere, não pode me largar aqui sozinho','medo'),
('temo pela sua segurança','medo'),
('eu te entrego o dinheiro, por favor não me mate!','medo'),
('ele vai levar todo o meu dinheiro','medo'),
('não dirija tão rápido assim','medo'),
('me descobriram, irão me prender!','medo'),
('só espero que não me façam nenhum mal','medo'),
('vou me afogar, me ajudem a sair da água','medo'),
('não estaremos a salvo aqui','medo'),
('não quero nem pensar no que pode acontecer','medo'),
('nessa cidade e uma desgraça atrás da outra','medo'),
('alguem esta me ligando, estou assustado','medo'),
('isso não e remedio, não me matem','medo'),
('eu não confio nele, tenho que ter cautela','medo'),
('muita cautela','medo'),
('vou ser descoberto, meu deus','medo'),
('receio que terei de ir','medo'),
('a noite e muito perigosa','medo'),
('estou estremecendo com essa casa','medo'),
('olha aquela criatura se movendo monstruosamente','medo'),
('não agüento este suspense','medo'),
('afugente os cães','medo'),
('estou chocado e amedrontado com este assassinato brutal','medo'),
('e preciso afugenta com ímpeto este medo do inferno','medo'),
('seu políticos usam suas forças para afugentar e amedrontar o povo','medo'),
('o objetivo disso e apenas me amedrontar mais','medo'),
('isso me apavora','medo'),
('que abominável esse montro!','medo'),
('vamos alarmar a todos sobre a situação','medo'),
('estou amedrontada','medo'),
('estou com muito medo da noite','medo'),
('ele esta me ameaçando a dias','medo'),
('quanta angustia','medo'),
('estou angustiada','medo'),
('angustiadamente vou sair e casa','medo'),
('isso me deixa apavorada','medo'),
('você esta me apavorando','medo'),
('estou desconfiada de você','medo'),
('não confio em você','medo'),
('ate o cachorro está apavorado','medo'),
('estou assustado com as ações do meu colega','medo'),
('agora se sente humilhado, apavorado','medo'),
('assustou a população e provocou mortes','medo'),
('estou com dificuldades para respirar e muito assustado','medo'),
('os policiais se assustaram quando o carro capotou','medo'),
('o trabalhador e assombrado pelo temor do desemprego','medo'),
('este lugar e mal assombrado','medo'),
('estou assombrado pela crise financeira','medo'),
('mesmo aterrorizado lembro de você','medo'),
('aterrorizado e suando frio','medo'),
('um grupo de elefantes selvagens tem aterrorizado vilas','medo'),
('me sinto intimidada pela sua presença','medo'),
('tenho medo de ser advertida novamente','medo'),
('estou correndo o risco de ser advertido','medo'),
('estou correndo riscos de saúde','medo'),
('os riscos são reais','medo'),
('podemos perder muito dinheiro com essa investida','medo'),
('socorro, fui intimado a depor','medo'),
('fui notificado e estou com medo de perde a guarda da minha filha','medo'),
('estou angustiada com meus filhos na rua','medo'),
('e abominável o que fazem com os animais','medo'),
('foi terrível o tigre quase o matou','medo'),
('Consegui meu diploma com honras!', 'alegria'),
('Recebi uma proposta de emprego dos meus sonhos.', 'alegria'),
('O casamento dos meus melhores amigos foi emocionante.', 'alegria'),
('Meu time venceu o campeonato!', 'alegria'),
('A surpresa de aniversário me deixou extremamente feliz.', 'alegria'),
('Encontrei meu cachorro perdido depois de dias de busca!', 'alegria'),
('A música me faz sorrir todos os dias.', 'alegria'),
('Estou radiante com o nascimento do meu filho.', 'alegria'),
('Ganhei um prêmio inesperado hoje!', 'alegria'),
('Fui aceito na universidade que eu sempre quis.', 'alegria'),
('Ouvi passos estranhos no corredor à noite.', 'medo'),
('Recebi uma ameaça anônima por telefone.', 'medo'),
('Ficar sozinho em uma casa abandonada é aterrorizante.', 'medo'),
('O filme de terror me deu pesadelos.', 'medo'),
('As notícias sobre um vírus desconhecido são assustadoras.', 'medo'),
('Aquela sombra na janela me deixa apavorado.', 'medo'),
('Algo se moveu no armário e me assustou.', 'medo'),
('Um estranho se aproximou de mim no beco escuro.', 'medo'),
('Perdi meu celular e estou com medo dos meus dados.', 'medo'),
('O barulho da tempestade me deixa assustado.', 'medo'),
('Consegui um novo emprego com um salário incrível!', 'alegria'),
('A viagem para a praia foi relaxante e alegre.', 'alegria'),
('Meu livro foi publicado e estou radiante!', 'alegria'),
('Recebi uma carta de amor surpresa.', 'alegria'),
('A festa de aniversário foi um sucesso!', 'alegria'),
('Comi meu bolo de chocolate favorito hoje.', 'alegria'),
('A montanha-russa me deixou emocionado.', 'alegria'),
('Ganhei um prêmio de fotografia.', 'alegria'),
('Assistir ao pôr do sol na praia é incrível.', 'alegria'),
('Estou feliz por ter tempo para minha família.', 'alegria'),
('Ouvi um barulho estranho no porão à noite.', 'medo'),
('A floresta à noite me dá arrepios.', 'medo'),
('Vi algo sinistro no canto do meu olho.', 'medo'),
('Recebi uma ligação com uma voz assustadora.', 'medo'),
('Aquela casa antiga é assustadora à noite.', 'medo'),
('Um grito ecoou no silêncio da noite.', 'medo'),
('Apareceu um vulto no espelho do banheiro.', 'medo'),
('O quarto escuro me deixa com medo.', 'medo'),
('A tempestade está ficando mais forte.', 'medo'),
('Os relatos de atividade paranormal são assustadores.', 'medo'),
('Estou emocionado por encontrar meu melhor amigo.', 'alegria'),
('Recebi uma mensagem adorável de um ente querido.', 'alegria'),
('As crianças brincando no parque me fazem sorrir.', 'alegria'),
('Comemorei meu aniversário com pessoas queridas.', 'alegria'),
('Assistir a um filme engraçado me deixa alegre.', 'alegria'),
('Recebi elogios pelo meu trabalho hoje.', 'alegria'),
('A surpresa de aniversário foi inesquecível.', 'alegria'),
('A notícia de que a família está vindo me alegra.', 'alegria'),
('Estou feliz por ter terminado meu projeto.', 'alegria'),
('Ouvi um barulho estranho no sótão à noite.', 'medo'),
('Recebi uma mensagem ameaçadora no meu e-mail.', 'medo'),
('A escuridão na floresta me deixa apreensivo.', 'medo'),
('Ouvi sussurros inquietantes no corredor.', 'medo'),
('Um vulto misterioso apareceu na foto.', 'medo'),
('Ficar sozinho em uma casa vazia é assustador.', 'medo'),
('O filme de terror me deu pesadelos à noite.', 'medo'),
('As notícias sobre crimes violentos me preocupam.', 'medo'),
('Aquela sombra na parede me deixa com medo.', 'medo'),
('A tempestade está se aproximando rapidamente.', 'medo'),
('Ganhei um sorteio e estou radiante!', 'alegria'),
('Encontrei uma nota antiga de amor e fiquei emocionado.', 'alegria'),
('Recebi uma carta de agradecimento inesperada.', 'alegria'),
('O nascer do sol nas montanhas é incrível.', 'alegria'),
('A notícia de que meu amigo está se recuperando é uma alegria.', 'alegria'),
('Estou animado com as férias planejadas.', 'alegria'),
('Meu time esportivo favorito ganhou o jogo.', 'alegria'),
('O cheiro de bolo assando enche a casa de alegria.', 'alegria'),
('Ver meu filho sorrindo me deixa radiante.', 'alegria'),
('Recebi um abraço caloroso de um amigo.', 'alegria'),
('Estou ansioso para encontrar minha família.', 'alegria'),
('Ouvir um barulho estranho me assusta.', 'medo'),
('Recebi uma ligação de um número desconhecido.', 'medo'),
('A figura na janela me dá arrepios.', 'medo'),
('Aquela casa abandonada é sinistra.', 'medo'),
('Ficar sozinho no escuro é assustador.', 'medo'),
('A notícia de um desastre natural me deixa apreensivo.', 'medo'),
('Vi algo se mover no canto do meu olho e me assustou.', 'medo'),
('As notícias de um novo vírus são aterrorizantes.', 'medo'),
('Um ruído no meio da noite me perturba.', 'medo'),
('O filme de terror me deixou tenso e nervoso.', 'medo'),
('Estou radiante com o nascimento do meu sobrinho!', 'alegria'),
('Ganhei um dia de spa como presente e estou feliz.', 'alegria'),
('Meu restaurante favorito reabriu.', 'alegria'),
('Recebi uma mensagem de texto adorável.', 'alegria'),
('Meu time marcou um gol no último minuto.', 'alegria'),
('Assistir ao pôr do sol na praia é maravilhoso.', 'alegria'),
('Estou contente por passar tempo com meus avós.', 'alegria'),
('Recebi um elogio do meu chefe.', 'alegria'),
('Comemorei meu aniversário com um bolo delicioso.', 'alegria'),
('Estou feliz por encontrar meu amigo depois de tanto tempo.', 'alegria'),
('Ouvi passos estranhos no corredor à noite.', 'medo'),
('Ficar sozinho em uma casa escura é assustador.', 'medo'),
('Vi uma figura assustadora na floresta.', 'medo'),
('Recebi uma mensagem de ameaça nas redes sociais.', 'medo'),
('O barulho do trovão me deixa apavorado.', 'medo'),
('Percebi sombras se movendo na sala.', 'medo'),
('Recebi uma ligação misteriosa no meio da noite.', 'medo'),
('A casa vazia à noite me deixa inquieto.', 'medo'),
('O filme de terror me deu arrepios.', 'medo'),
('As notícias de um desastre natural me preocupam.', 'medo'),
('Estou emocionado por ser surpreendido com uma festa.', 'alegria'),
('Recebi uma carta de agradecimento emocionante.', 'alegria'),
('Meu livro favorito foi adaptado para um filme.', 'alegria'),
('Fiz uma viagem inesperada e estou radiante.', 'alegria'),
('Meu time esportivo favorito está indo para as finais.', 'alegria'),
('Estou animado para conhecer novas pessoas.', 'alegria'),
('A surpresa do meu amigo me deixou muito feliz.', 'alegria'),
('Recebi um presente especial de aniversário.', 'alegria'),
('O nascer do sol na montanha é deslumbrante.', 'alegria'),
('Estou feliz por ter tempo para minhas paixões.', 'alegria'),
('Ouvi um ruído estranho no sótão.', 'medo'),
('Recebi uma mensagem assustadora de um número desconhecido.', 'medo'),
('Aquela sombra na janela me deixa apreensivo.', 'medo'),
('Vi algo sinistro no canto do meu olho.', 'medo'),
('Recebi um e-mail ameaçador.', 'medo'),
('A tempestade está se aproximando rapidamente.', 'medo'),
('A notícia de um crime na minha vizinhança é perturbadora.', 'medo'),
('Algo se moveu no armário e me assustou.', 'medo'),
('Ouvi passos no corredor vazio à noite.', 'medo'),
('O filme de terror me deixa com medo.', 'medo'),
('Encontrei meu amigo depois de muito tempo e estou alegre.', 'alegria'),
('Recebi uma mensagem de amor inesperada.', 'alegria'),
('As crianças brincando no parque me fazem sorrir.', 'alegria'),
('Comemorei meu aniversário com uma festa surpresa.', 'alegria'),
('Assistir a um filme engraçado me deixa alegre.', 'alegria'),
('Recebi elogios pelo meu trabalho hoje.', 'alegria'),
('A surpresa de aniversário foi inesquecível.', 'alegria'),
('A notícia de que a família está vindo me alegra.', 'alegria'),
('Estou feliz por ter terminado meu projeto.', 'alegria'),
('Ouvi um barulho estranho no porão à noite.', 'medo'),
('Recebi uma mensagem ameaçadora no meu e-mail.', 'medo'),
('A escuridão na floresta me deixa apreensivo.', 'medo'),
('Ouvi sussurros inquietantes no corredor.', 'medo'),
('Um vulto misterioso apareceu na foto.', 'medo'),
('Ficar sozinho em uma casa vazia é assustador.', 'medo'),
('O filme de terror me deu pesadelos à noite.', 'medo'),
('As notícias sobre crimes violentos me preocupam.', 'medo'),
('Aquela sombra na parede me deixa com medo.', 'medo'),
('A tempestade está ficando mais forte.', 'medo'),
('Ganhei um sorteio e estou radiante!', 'alegria'),
('Encontrei uma nota antiga de amor e fiquei emocionado.', 'alegria'),
('Recebi uma carta de agradecimento inesperada.', 'alegria'),
('O nascer do sol nas montanhas é incrível.', 'alegria'),
('A notícia de que meu amigo está se recuperando é uma alegria.', 'alegria'),
('Estou animado com as férias planejadas.', 'alegria'),
('Meu time esportivo favorito ganhou o jogo.', 'alegria'),
('O cheiro de bolo assando enche a casa de alegria.', 'alegria'),
('Ver meu filho sorrindo me deixa radiante.', 'alegria'),
('Recebi um abraço caloroso de um amigo.', 'alegria'),
('Estou ansioso para encontrar minha família.', 'alegria'),
('Ouvir um barulho estranho me assusta.', 'medo'),
('Recebi uma ligação de um número desconhecido.', 'medo'),
('A figura na janela me dá arrepios.', 'medo'),
('Aquela casa abandonada é sinistra.', 'medo'),
('Ficar sozinho no escuro é assustador.', 'medo'),
('A notícia de um novo vírus me deixa apreensivo.', 'medo'),
('Vi algo se mover no canto do meu olho e me assustou.', 'medo'),
('As notícias de um desastre natural me preocupam.', 'medo'),
('Um ruído no meio da noite me perturba.', 'medo'),
('O filme de terror me deixou tenso e nervoso.', 'medo'),
('Estou radiante com o nascimento do meu sobrinho!', 'alegria'),
('Ganhei um dia de spa como presente e estou feliz.', 'alegria'),
('Meu restaurante favorito reabriu.', 'alegria'),
('Recebi uma mensagem de texto adorável.', 'alegria'),
('Meu time marcou um gol no último minuto.', 'alegria'),
('Assistir ao pôr do sol na praia é maravilhoso.', 'alegria'),
('Estou contente por passar tempo com meus avós.', 'alegria'),
('Recebi um elogio do meu chefe.', 'alegria'),
('Comemorei meu aniversário com um bolo delicioso.', 'alegria'),
('Estou feliz por encontrar meu amigo depois de tanto tempo.', 'alegria'),
('Ouvi passos estranhos no corredor à noite.', 'medo'),
('Ficar sozinho em uma casa escura é assustador.', 'medo'),
('Vi uma figura assustadora na floresta.', 'medo'),
('Recebi uma mensagem de ameaça nas redes sociais.', 'medo'),
('O barulho do trovão me deixa apavorado.', 'medo'),
('Percebi sombras se movendo na sala.', 'medo'),
('Recebi uma ligação misteriosa no meio da noite.', 'medo'),
('A casa vazia à noite me deixa inquieto.', 'medo'),
('O filme de terror me deixa com medo.', 'medo'),
('As notícias de um desastre natural me preocupam.', 'medo'),
('Estou emocionado por ser surpreendido com uma festa.', 'alegria'),
('Recebi uma carta de agradecimento emocionante.', 'alegria'),
('Meu livro favorito foi adaptado para um filme.', 'alegria'),
('Fiz uma viagem inesperada e estou radiante.', 'alegria'),
('Meu time esportivo favorito está indo para as finais.', 'alegria'),
('Estou animado para conhecer novas pessoas.', 'alegria'),
('A surpresa do meu amigo me deixou muito feliz.', 'alegria'),
('Recebi um presente especial de aniversário.', 'alegria'),
('O nascer do sol na montanha é deslumbrante.', 'alegria'),
('Estou feliz por ter tempo para minhas paixões.', 'alegria'),
('Ouvi um ruído estranho no sótão.', 'medo'),
('Recebi uma mensagem assustadora de um número desconhecido.', 'medo'),
('Aquela sombra na janela me deixa apreensivo.', 'medo'),
('Vi algo sinistro no canto do meu olho.', 'medo'),
('Recebi um e-mail ameaçador.', 'medo'),
('A tempestade está se aproximando rapidamente.', 'medo'),
('A notícia de um crime na minha vizinhança é perturbadora.', 'medo'),
('Algo se moveu no armário e me assustou.', 'medo'),
('Ouvi passos no corredor vazio à noite.', 'medo'),
('O filme de terror me deixa com medo.', 'medo'),
('Encontrei meu amigo depois de muito tempo e estou alegre.', 'alegria'),
('Recebi uma mensagem de amor inesperada.', 'alegria'),
('As crianças brincando no parque me fazem sorrir.', 'alegria'),
('Comemorei meu aniversário com uma festa surpresa.', 'alegria'),
('Assistir a um filme engraçado me deixa alegre.', 'alegria'),
('Recebi elogios pelo meu trabalho hoje.', 'alegria'),
('A surpresa de aniversário foi inesquecível.', 'alegria'),
('A notícia de que a família está vindo me alegra.', 'alegria'),
('Estou feliz por ter terminado meu projeto.', 'alegria'),
('Ouvi um barulho estranho no porão à noite.', 'medo'),
('Recebi uma mensagem ameaçadora no meu e-mail.', 'medo'),
('A escuridão na floresta me deixa apreensivo.', 'medo'),
('Ouvi sussurros inquietantes no corredor.', 'medo'),
('Um vulto misterioso apareceu na foto.', 'medo'),
('Ficar sozinho em uma casa vazia é assustador.', 'medo'),
('O filme de terror me deu pesadelos à noite.', 'medo'),
('As notícias sobre crimes violentos me preocupam.', 'medo'),
('Aquela sombra na parede me deixa com medo.', 'medo'),
('A tempestade está ficando mais forte.', 'medo'),
('Ganhei um sorteio e estou radiante!', 'alegria'),
('Encontrei uma nota antiga de amor e fiquei emocionado.', 'alegria'),
('Recebi uma carta de agradecimento inesperada.', 'alegria'),
('O nascer do sol nas montanhas é incrível.', 'alegria'),
('A notícia de que meu amigo está se recuperando é uma alegria.', 'alegria'),
('Estou animado com as férias planejadas.', 'alegria'),
('Meu time esportivo favorito ganhou o jogo.', 'alegria'),
('O cheiro de bolo assando enche a casa de alegria.', 'alegria'),
('Ver meu filho sorrindo me deixa radiante.', 'alegria'),
('Recebi um abraço caloroso de um amigo.', 'alegria'),
('Estou ansioso para encontrar minha família.', 'alegria'),
('Ouvir um barulho estranho me assusta.', 'medo'),
('Recebi uma ligação de um número desconhecido.', 'medo'),
('A figura na janela me dá arrepios.', 'medo'),
('Aquela casa abandonada é sinistra.', 'medo'),
('Ficar sozinho no escuro é assustador.', 'medo'),
('A notícia de um novo vírus me deixa apreensivo.', 'medo'),
('Vi algo se mover no canto do meu olho e me assustou.', 'medo'),
('As notícias de um desastre natural me preocupam.', 'medo'),
('Um ruído no meio da noite me perturba.', 'medo'),
('O filme de terror me deixou tenso e nervoso.', 'medo'),
('Estou radiante com o nascimento do meu sobrinho!', 'alegria'),
('Ganhei um dia de spa como presente e estou feliz.', 'alegria'),
('Meu restaurante favorito reabriu.', 'alegria'),
('Recebi uma mensagem de texto adorável.', 'alegria'),
('Meu time marcou um gol no último minuto.', 'alegria'),
('Assistir ao pôr do sol na praia é maravilhoso.', 'alegria'),
('Estou contente por passar tempo com meus avós.', 'alegria'),
('Recebi um elogio do meu chefe.', 'alegria'),
('Comemorei meu aniversário com um bolo delicioso.', 'alegria'),
('Estou feliz por encontrar meu amigo depois de tanto tempo.', 'alegria'),
('Ouvi passos estranhos no corredor à noite.', 'medo'),
('Ficar sozinho em uma casa escura é assustador.', 'medo'),
('Vi uma figura assustadora na floresta.', 'medo'),
('Recebi uma mensagem de ameaça nas redes sociais.', 'medo'),
('O barulho do trovão me deixa apavorado.', 'medo'),
('Percebi sombras se movendo na sala.', 'medo'),
('Recebi uma ligação misteriosa no meio da noite.', 'medo'),
('A casa vazia à noite me deixa inquieto.', 'medo'),
('O filme de terror me deixa com medo.', 'medo'),
('As notícias de um desastre natural me preocupam.', 'medo'),
('Estou emocionado por ser surpreendido com uma festa.', 'alegria'),
('Recebi uma carta de agradecimento emocionante.', 'alegria'),
('Meu livro favorito foi adaptado para um filme.', 'alegria'),
('Fiz uma viagem inesperada e estou radiante.', 'alegria'),
('Meu time esportivo favorito está indo para as finais.', 'alegria'),
('Estou animado para conhecer novas pessoas.', 'alegria'),
('A surpresa do meu amigo me deixou muito feliz.', 'alegria'),
('Recebi um presente especial de aniversário.', 'alegria'),
('O nascer do sol na montanha é deslumbrante.', 'alegria'),
('Estou feliz por ter tempo para minhas paixões.', 'alegria'),
('Ouvi um ruído estranho no sótão.', 'medo'),
('Recebi uma mensagem assustadora de um número desconhecido.', 'medo'),
('Aquela sombra na janela me deixa apreensivo.', 'medo'),
('Vi algo sinistro no canto do meu olho.', 'medo'),
('Recebi um e-mail ameaçador.', 'medo'),
('A tempestade está se aproximando rapidamente.', 'medo'),
('A notícia de um crime na minha vizinhança é perturbadora.', 'medo'),
('Algo se moveu no armário e me assustou.', 'medo'),
('Ouvi passos no corredor vazio à noite.', 'medo'),
('O filme de terror me deixa com medo.', 'medo'),
('Encontrei meu amigo depois de muito tempo e estou alegre.', 'alegria'),
('Recebi uma mensagem de amor inesperada.', 'alegria'),
('As crianças brincando no parque me fazem sorrir.', 'alegria'),
('Comemorei meu aniversário com uma festa surpresa.', 'alegria'),
('Assistir a um filme engraçado me deixa alegre.', 'alegria'),
('Recebi elogios pelo meu trabalho hoje.', 'alegria'),
('A surpresa de aniversário foi inesquecível.', 'alegria'),
('A notícia de que a família está vindo me alegra.', 'alegria'),
('Estou feliz por ter terminado meu projeto.', 'alegria'),
('Ouvi um barulho estranho no porão à noite.', 'medo'),
('Recebi uma mensagem ameaçadora no meu e-mail.', 'medo'),
('A escuridão na floresta me deixa apreensivo.', 'medo'),
('Ouvi sussurros inquietantes no corredor.', 'medo'),
('Um vulto misterioso apareceu na foto.', 'medo'),
('Ficar sozinho em uma casa vazia é assustador.', 'medo'),
('O filme de terror me deu pesadelos à noite.', 'medo'),
('As notícias sobre crimes violentos me preocupam.', 'medo'),
('Aquela sombra na parede me deixa com medo.', 'medo'),
('A tempestade está ficando mais forte.', 'medo'),
('Ganhei um sorteio e estou radiante!', 'alegria'),
('Encontrei uma nota antiga de amor e fiquei emocionado.', 'alegria'),
('Recebi uma carta de agradecimento inesperada.', 'alegria'),
('O nascer do sol nas montanhas é incrível.', 'alegria'),
('A notícia de que meu amigo está se recuperando é uma alegria.', 'alegria'),
('Estou animado com as férias planejadas.', 'alegria'),
('Meu time esportivo favorito ganhou o jogo.', 'alegria'),
('O cheiro de bolo assando enche a casa de alegria.', 'alegria'),
('Ver meu filho sorrindo me deixa radiante.', 'alegria'),
('Recebi um abraço caloroso de um amigo.', 'alegria'),
('Estou ansioso para encontrar minha família.', 'alegria'),
('Ouvir um barulho estranho me assusta.', 'medo'),
('Recebi uma ligação de um número desconhecido.', 'medo'),
('A figura na janela me dá arrepios.', 'medo'),
('Aquela casa abandonada é sinistra.', 'medo'),
('Ficar sozinho no escuro é assustador.', 'medo'),
('A notícia de um novo vírus me deixa apreensivo.', 'medo'),
('Vi algo se mover no canto do meu olho e me assustou.', 'medo'),
('As notícias de um desastre natural me preocupam.', 'medo'),
('Um ruído no meio da noite me perturba.', 'medo'),
('O filme de terror me deixou tenso e nervoso.', 'medo'),
('Estou radiante com o nascimento do meu sobrinho!', 'alegria'),
('Ganhei um dia de spa como presente e estou feliz.', 'alegria'),
('Meu restaurante favorito reabriu.', 'alegria'),
('Recebi uma mensagem de texto adorável.', 'alegria'),
('Meu time marcou um gol no último minuto.', 'alegria'),
('Assistir ao pôr do sol na praia é maravilhoso.', 'alegria'),
('Estou contente por passar tempo com meus avós.', 'alegria'),
('Recebi um elogio do meu chefe.', 'alegria'),
('Comemorei meu aniversário com um bolo delicioso.', 'alegria'),
('Estou feliz por encontrar meu amigo depois de tanto tempo.', 'alegria'),
('Ouvi passos estranhos no corredor à noite.', 'medo'),
('Ficar sozinho em uma casa escura é assustador.', 'medo'),
('Vi uma figura assustadora na floresta.', 'medo'),
('Recebi uma mensagem de ameaça nas redes sociais.', 'medo'),
('O barulho do trovão me deixa apavorado.', 'medo'),
('Percebi sombras se movendo na sala.', 'medo'),
('Recebi uma ligação misteriosa no meio da noite.', 'medo'),
('A casa vazia à noite me deixa inquieto.', 'medo'),
('O filme de terror me deixa com medo.', 'medo'),
('As notícias de um desastre natural me preocupam.', 'medo'),
('Estou emocionado por ser surpreendido com uma festa.', 'alegria'),
('Recebi uma carta de agradecimento emocionante.', 'alegria'),
('Meu livro favorito foi adaptado para um filme.', 'alegria'),
('Fiz uma viagem inesperada e estou radiante.', 'alegria'),
('Meu time esportivo favorito está indo para as finais.', 'alegria'),
('Estou animado para conhecer novas pessoas.', 'alegria'),
('A surpresa do meu amigo me deixou muito feliz.', 'alegria'),
('Recebi um presente especial de aniversário.', 'alegria'),
('O nascer do sol na montanha é deslumbrante.', 'alegria'),
('Estou feliz por ter tempo para minhas paixões.', 'alegria'),
('Ouvi um ruído estranho no sótão.', 'medo'),
('Recebi uma mensagem assustadora de um número desconhecido.', 'medo'),
('Aquela sombra na janela me deixa apreensivo.', 'medo'),
('Vi algo sinistro no canto do meu olho.', 'medo'),
('Recebi um e-mail ameaçador.', 'medo'),
('A tempestade está se aproximando rapidamente.', 'medo'),
('A notícia de um crime na minha vizinhança é perturbadora.', 'medo'),
('Algo se moveu no armário e me assustou.', 'medo'),
('Ouvi passos no corredor vazio à noite.', 'medo'),
('O filme de terror me deixa com medo.', 'medo'),
('Encontrei meu amigo depois de muito tempo e estou alegre.', 'alegria'),
('Recebi uma mensagem de amor inesperada.', 'alegria'),
('As crianças brincando no parque me fazem sorrir.', 'alegria'),
('Comemorei meu aniversário com uma festa surpresa.', 'alegria'),
('Assistir a um filme engraçado me deixa alegre.', 'alegria'),
('Recebi elogios pelo meu trabalho hoje.', 'alegria'),
('A surpresa de aniversário foi inesquecível.', 'alegria'),
('A notícia de que a família está vindo me alegra.', 'alegria'),
('Estou feliz por ter terminado meu projeto.', 'alegria'),
('Ouvi um barulho estranho no porão à noite.', 'medo'),
('Recebi uma mensagem ameaçadora no meu e-mail.', 'medo'),
('A escuridão na floresta me deixa apreensivo.', 'medo'),
('Ouvi sussurros inquietantes no corredor.', 'medo'),
('Um vulto misterioso apareceu na foto.', 'medo'),
('Ficar sozinho em uma casa vazia é assustador.', 'medo'),
('O filme de terror me deu pesadelos à noite.', 'medo'),
('As notícias sobre crimes violentos me preocupam.', 'medo'),
('Aquela sombra na parede me deixa com medo.', 'medo'),
('A tempestade está ficando mais forte.', 'medo'),
('Ganhei um sorteio e estou radiante!', 'alegria'),
('Encontrei uma nota antiga de amor e fiquei emocionado.', 'alegria'),
('Recebi uma carta de agradecimento inesperada.', 'alegria'),
('O nascer do sol nas montanhas é incrível.', 'alegria'),
('A notícia de que meu amigo está se recuperando é uma alegria.', 'alegria'),
('Estou animado com as férias planejadas.', 'alegria'),
('Meu time esportivo favorito ganhou o jogo.', 'alegria'),
('O cheiro de bolo assando enche a casa de alegria.', 'alegria'),
('Ver meu filho sorrindo me deixa radiante.', 'alegria'),
('Recebi um abraço caloroso de um amigo.', 'alegria'),
('Estou ansioso para encontrar minha família.', 'alegria'),
('Ouvir um barulho estranho me assusta.', 'medo'),
('Recebi uma ligação de um número desconhecido.', 'medo'),
('A figura na janela me dá arrepios.', 'medo'),
('Aquela casa abandonada é sinistra.', 'medo'),
('Ficar sozinho no escuro é assustador.', 'medo'),
('A notícia de um novo vírus me deixa apreensivo.', 'medo'),
('Vi algo se mover no canto do meu olho e me assustou.', 'medo'),
('As notícias de um desastre natural me preocupam.', 'medo'),
('Um ruído no meio da noite me perturba.', 'medo'),
('O filme de terror me deixou tenso e nervoso.', 'medo'),
('me advertiram sobre isso','medo')]

# %%
import numpy as np
import pandas as pd

# %%
type(base)
# Out:
# list

# %% [markdown]
# ## Convertendo uma Lista em um  Dataframe

# %%
basenova = pd.DataFrame(base, columns = ['frase','sentimento'])

# %%
basenova
# Out:
#                                                  frase sentimento
# 0                        não precisei pagar o ingresso    alegria
# 1                          se eu ajeitar tudo fica bem    alegria
# 2                       minha fortuna ultrapassa a sua    alegria
# 3                                 sou muito afortunado    alegria
# 4               e benefico para todos esta nova medida    alegria
# ..                                                 ...        ...
# 675  Vi algo se mover no canto do meu olho e me ass...       medo
# 676   As notícias de um desastre natural me preocupam.       medo
# 677             Um ruído no meio da noite me perturba.       medo
# 678       O filme de terror me deixou tenso e nervoso.       medo
# 679                           me advertiram sobre isso       medo
#
# [680 rows x 2 columns]

# %%
#Embraralhando a base
import sklearn
basenova = sklearn.utils.shuffle(basenova)

# %%
basenova
# Out:
#                                            frase sentimento
# 446               Recebi um elogio do meu chefe.    alegria
# 53                        adoro seu cabelo macio    alegria
# 131                           eu sou sua rainha     alegria
# 487   Estou feliz por ter terminado meu projeto.    alegria
# 167               este lugar continua assustador       medo
# ..                                           ...        ...
# 536      A casa vazia à noite me deixa inquieto.       medo
# 348  Estou ansioso para encontrar minha família.    alegria
# 66                            como o luar e belo    alegria
# 52                             adoro como você e    alegria
# 289   Ouvi passos estranhos no corredor à noite.       medo
#
# [680 rows x 2 columns]

# %%
#para acessar um item quando é uma lista
base[1]
# Out:
# ('se eu ajeitar tudo fica bem', 'alegria')

# %%
#para acessar um item quando é um dataframe
basenova.iloc[[1]]
# Out:
#                      frase sentimento
# 53  adoro seu cabelo macio    alegria

# %%
#quantidade de linhas de um dataframe
basenova.shape
# Out:
# (680, 2)

# %%
#quantidade de linhas de uma lista
len(base)
# Out:
# 680

# %%
import seaborn as sns
sns.countplot(x= basenova['sentimento'], label = 'Contagem');

# %% [markdown]
# ## Separar texto do rótulo - O sentimento é o que queremos prever, então fica separado.

# %%
frases = basenova[['frase']]
sentimento = basenova['sentimento'].values

# %%
frases.head()
# Out:
#                                           frase
# 446              Recebi um elogio do meu chefe.
# 53                       adoro seu cabelo macio
# 131                          eu sou sua rainha
# 487  Estou feliz por ter terminado meu projeto.
# 167              este lugar continua assustador

# %%
sentimento
# Out:
# array(['alegria', 'alegria', 'alegria', 'alegria', 'medo', 'medo',
#        'alegria', 'medo', 'alegria', 'alegria', 'alegria', 'alegria',
#        'alegria', 'medo', 'alegria', 'alegria', 'alegria', 'alegria',
#        'alegria', 'medo', 'alegria', 'medo', 'alegria', 'medo', 'medo',
#        'alegria', 'alegria', 'alegria', 'medo', 'medo', 'medo', 'medo',
#        'alegria', 'alegria', 'alegria', 'medo', 'medo', 'alegria',
#        'alegria', 'alegria', 'alegria', 'medo', 'medo', 'alegria',
#        'alegria', 'medo', 'medo', 'medo', 'medo', 'medo', 'medo',
#        'alegria', 'alegria', 'alegria', 'alegria', 'alegria', 'alegria',
#        'alegria', 'medo', 'medo', 'medo', 'alegria', 'medo', 'medo',
#        'medo', 'alegria', 'medo', 'alegria', 'alegria', 'alegria',
#        'alegria', 'alegria', 'medo', 'alegria', 'alegria', 'alegria',
#        'medo', 'alegria', 'alegria', 'alegria', 'alegria', 'alegria',
#        'medo', 'medo', 'medo', 'alegria', 'alegria', 'alegria', 'alegria',
#        'medo', 'alegria', 'medo', 'medo', 'alegria', 'alegria', 'medo',
#        'medo', 'medo', 'medo', 'alegria', 'alegria', 'alegria', 'alegria',
#        'medo', 'alegria', 'alegria', 'medo', 'alegria', 'alegria',
#        'alegria', 'alegria', 'medo', 'medo', 'alegria', 'alegria', 'medo',
#        'medo', 'alegria', 'alegria', 'medo', 'alegria', 'alegria', 'medo',
#        'medo', 'alegria', 'medo', 'medo', 'medo', 'alegria', 'medo',
#        'alegria', 'alegria', 'medo', 'alegria', 'alegria', 'medo',
#        'alegria', 'alegria', 'medo', 'medo', 'medo', 'medo', 'medo',
#        'medo', 'alegria', 'alegria', 'medo', 'medo', 'alegria', 'alegria',
#        'alegria', 'medo', 'alegria', 'alegria', 'alegria', 'medo', 'medo',
#        'alegria', 'medo', 'medo', 'alegria', 'alegria', 'medo', 'alegria',
#        'medo', 'medo', 'medo', 'alegria', 'alegria', 'alegria', 'medo',
#        'alegria', 'alegria', 'medo', 'medo', 'alegria', 'medo', 'medo',
#        'medo', 'alegria', 'alegria', 'medo', 'medo', 'alegria', 'medo',
#        'alegria', 'medo', 'alegria', 'medo', 'medo', 'alegria', 'medo',
#        'alegria', 'medo', 'medo', 'alegria', 'alegria', 'alegria',
#        'alegria', 'medo', 'medo', 'alegria', 'medo', 'medo', 'alegria',
#        'alegria', 'medo', 'alegria', 'medo', 'medo', 'alegria', 'alegria',
#        'medo', 'medo', 'medo', 'alegria', 'medo', 'medo', 'medo',
#        'alegria', 'alegria', 'medo', 'alegria', 'alegria', 'medo', 'medo',
#        'alegria', 'alegria', 'alegria', 'medo', 'alegria', 'alegria',
#        'medo', 'medo', 'alegria', 'medo', 'alegria', 'medo', 'alegria',
#        'alegria', 'medo', 'medo', 'medo', 'alegria', 'alegria', 'alegria',
#        'medo', 'alegria', 'medo', 'alegria', 'medo', 'alegria', 'medo',
#        'alegria', 'alegria', 'alegria', 'medo', 'alegria', 'medo', 'medo',
#        'medo', 'medo', 'alegria', 'medo', 'alegria', 'alegria', 'alegria',
#        'medo', 'alegria', 'medo', 'alegria', 'alegria', 'alegria', 'medo',
#        'medo', 'medo', 'medo', 'medo', 'alegria', 'alegria', 'medo',
#        'alegria', 'alegria', 'medo', 'alegria', 'alegria', 'medo',
#        'alegria', 'medo', 'medo', 'medo', 'alegria', 'alegria', 'alegria',
#        'medo', 'medo', 'medo', 'alegria', 'alegria', 'alegria', 'medo',
#        'medo', 'alegria', 'alegria', 'medo', 'medo', 'alegria', 'alegria',
#        'medo', 'medo', 'medo', 'alegria', 'alegria', 'alegria', 'alegria',
#        'alegria', 'alegria', 'medo', 'alegria', 'medo', 'medo', 'alegria',
#        'alegria', 'medo', 'medo', 'medo', 'medo', 'medo', 'medo', 'medo',
#        'alegria', 'medo', 'alegria', 'medo', 'alegria', 'medo', 'medo',
#        'medo', 'alegria', 'medo', 'medo', 'medo', 'alegria', 'alegria',
#        'medo', 'alegria', 'alegria', 'alegria', 'alegria', 'medo',
#        'alegria', 'alegria', 'medo', 'alegria', 'alegria', 'medo', 'medo',
#        'alegria', 'alegria', 'medo', 'medo', 'medo', 'alegria', 'alegria',
#        'alegria', 'alegria', 'alegria', 'medo', 'medo', 'medo', 'alegria',
#        'medo', 'alegria', 'medo', 'medo', 'medo', 'medo', 'medo',
#        'alegria', 'alegria', 'medo', 'medo', 'medo', 'alegria', 'alegria',
#        'medo', 'medo', 'medo', 'alegria', 'medo', 'medo', 'alegria',
#        'alegria', 'medo', 'medo', 'medo', 'alegria', 'medo', 'alegria',
#        'alegria', 'alegria', 'medo', 'alegria', 'alegria', 'alegria',
#        'alegria', 'alegria', 'medo', 'medo', 'medo', 'alegria', 'alegria',
#        'medo', 'alegria', 'medo', 'medo', 'medo', 'medo', 'alegria',
#        'medo', 'alegria', 'medo', 'medo', 'medo', 'medo', 'alegria',
#        'alegria', 'medo', 'medo', 'medo', 'medo', 'medo', 'medo', 'medo',
#        'alegria', 'medo', 'alegria', 'alegria', 'medo', 'medo', 'medo',
#        'alegria', 'medo', 'medo', 'alegria', 'alegria', 'alegria',
#        'alegria', 'medo', 'medo', 'alegria', 'medo', 'alegria', 'medo',
#        'alegria', 'medo', 'medo', 'alegria', 'medo', 'alegria', 'medo',
#        'alegria', 'alegria', 'medo', 'alegria', 'medo', 'alegria', 'medo',
#        'alegria', 'alegria', 'alegria', 'medo', 'medo', 'alegria', 'medo',
#        'medo', 'alegria', 'alegria', 'medo', 'alegria', 'alegria',
#        'alegria', 'alegria', 'alegria', 'medo', 'medo', 'alegria',
#        'alegria', 'alegria', 'alegria', 'alegria', 'alegria', 'medo',
#        'medo', 'alegria', 'alegria', 'alegria', 'alegria', 'alegria',
#        'medo', 'alegria', 'medo', 'medo', 'alegria', 'alegria', 'medo',
#        'alegria', 'alegria', 'alegria', 'alegria', 'alegria', 'medo',
#        'medo', 'medo', 'alegria', 'medo', 'alegria', 'medo', 'medo',
#        'alegria', 'medo', 'medo', 'alegria', 'medo', 'alegria', 'alegria',
#        'medo', 'medo', 'medo', 'medo', 'medo', 'medo', 'medo', 'alegria',
#        'medo', 'alegria', 'medo', 'medo', 'medo', 'medo', 'alegria',
#        'alegria', 'medo', 'medo', 'alegria', 'medo', 'medo', 'alegria',
#        'alegria', 'medo', 'medo', 'alegria', 'alegria', 'alegria', 'medo',
#        'alegria', 'alegria', 'alegria', 'medo', 'medo', 'medo', 'medo',
#        'alegria', 'alegria', 'alegria', 'medo', 'alegria', 'medo', 'medo',
#        'alegria', 'alegria', 'alegria', 'alegria', 'alegria', 'alegria',
#        'medo', 'alegria', 'alegria', 'alegria', 'alegria', 'alegria',
#        'alegria', 'medo', 'alegria', 'alegria', 'alegria', 'alegria',
#        'medo', 'alegria', 'medo', 'medo', 'alegria', 'alegria', 'medo',
#        'alegria', 'alegria', 'alegria', 'medo', 'alegria', 'alegria',
#        'alegria', 'alegria', 'alegria', 'alegria', 'medo', 'alegria',
#        'alegria', 'medo', 'alegria', 'medo', 'medo', 'medo', 'alegria',
#        'medo', 'medo', 'alegria', 'alegria', 'medo', 'medo', 'medo',
#        'medo', 'medo', 'medo', 'alegria', 'alegria', 'alegria', 'medo',
#        'alegria', 'alegria', 'medo', 'alegria', 'medo', 'alegria',
#        'alegria', 'alegria', 'alegria', 'medo', 'alegria', 'alegria',
#        'alegria', 'alegria', 'medo', 'medo', 'alegria', 'medo', 'alegria',
#        'alegria', 'medo', 'medo', 'alegria', 'alegria', 'medo', 'alegria',
#        'medo', 'medo', 'alegria', 'medo', 'medo', 'alegria', 'medo',
#        'alegria', 'alegria', 'alegria', 'medo', 'medo', 'medo', 'alegria',
#        'alegria', 'alegria', 'alegria', 'alegria', 'medo', 'medo',
#        'alegria', 'alegria', 'medo', 'alegria', 'alegria', 'alegria',
#        'medo'], dtype=object)

# %% [markdown]
# ## Remoção das Stop Words apenas das frases, realmente ver se vale a pena fazer com ou sem.

# %%
#posso criar minha própria lista de stop words
'''stopwords = ['a', 'agora', 'algum', 'alguma', 'aquele', 'aqueles', 'de', 'deu', 'do', 'e', 'estou', 'esta', 'esta',
             'ir', 'meu', 'muito', 'mesmo', 'no', 'nossa', 'o', 'outro', 'para', 'que', 'sem', 'talvez', 'tem', 'tendo',
             'tenha', 'teve', 'tive', 'todo', 'um', 'uma', 'umas', 'uns', 'vou']'''
# Out:
# "stopwords = ['a', 'agora', 'algum', 'alguma', 'aquele', 'aqueles', 'de', 'deu', 'do', 'e', 'estou', 'esta', 'esta',\n             'ir', 'meu', 'muito', 'mesmo', 'no', 'nossa', 'o', 'outro', 'para', 'que', 'sem', 'talvez', 'tem', 'tendo',\n             'tenha', 'teve', 'tive', 'todo', 'um', 'uma', 'umas', 'uns', 'vou']"

# %%
#ou posso fazer o download de uma
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
#pegando em portugues
stopwordsnltk = nltk.corpus.stopwords.words('portuguese')

# %%
stopwordsnltk
# Out:
# ['a',
#  'à',
#  'ao',
#  'aos',
#  'aquela',
#  'aquelas',
#  'aquele',
#  'aqueles',
#  'aquilo',
#  'as',
#  'às',
#  'até',
#  'com',
#  'como',
#  'da',
#  'das',
#  'de',
#  'dela',
#  'delas',
#  'dele',
#  'deles',
#  'depois',
#  'do',
#  'dos',
#  'e',
#  'é',
#  'ela',
#  'elas',
#  'ele',
#  'eles',
#  'em',
#  'entre',
#  'era',
#  'eram',
#  'éramos',
#  'essa',
#  'essas',
#  'esse',
#  'esses',
#  'esta',
#  'está',
#  'estamos',
#  'estão',
#  'estar',
#  'estas',
#  'estava',
#  'estavam',
#  'estávamos',
#  'este',
#  'esteja',
#  'estejam',
#  'estejamos',
#  'estes',
#  'esteve',
#  'estive',
#  'estivemos',
#  'estiver',
#  'estivera',
#  'estiveram',
#  'estivéramos',
#  'estiverem',
#  'estivermos',
#  'estivesse',
#  'estivessem',
#  'estivéssemos',
#  'estou',
#  'eu',
#  'foi',
#  'fomos',
#  'for',
#  'fora',
#  'foram',
#  'fôramos',
#  'forem',
#  'formos',
#  'fosse',
#  'fossem',
#  'fôssemos',
#  'fui',
#  'há',
#  'haja',
#  'hajam',
#  'hajamos',
#  'hão',
#  'havemos',
#  'haver',
#  'hei',
#  'houve',
#  'houvemos',
#  'houver',
#  'houvera',
#  'houverá',
#  'houveram',
#  'houvéramos',
#  'houverão',
#  'houverei',
#  'houverem',
#  'houveremos',
#  'houveria',
#  'houveriam',
#  'houveríamos',
#  'houvermos',
#  'houvesse',
#  'houvessem',
#  'houvéssemos',
#  'isso',
#  'isto',
#  'já',
#  'lhe',
#  'lhes',
#  'mais',
#  'mas',
#  'me',
#  'mesmo',
#  'meu',
#  'meus',
#  'minha',
#  'minhas',
#  'muito',
#  'na',
#  'não',
#  'nas',
#  'nem',
#  'no',
#  'nos',
#  'nós',
#  'nossa',
#  'nossas',
#  'nosso',
#  'nossos',
#  'num',
#  'numa',
#  'o',
#  'os',
#  'ou',
#  'para',
#  'pela',
#  'pelas',
#  'pelo',
#  'pelos',
#  'por',
#  'qual',
#  'quando',
#  'que',
#  'quem',
#  'são',
#  'se',
#  'seja',
#  'sejam',
#  'sejamos',
#  'sem',
#  'ser',
#  'será',
#  'serão',
#  'serei',
#  'seremos',
#  'seria',
#  'seriam',
#  'seríamos',
#  'seu',
#  'seus',
#  'só',
#  'somos',
#  'sou',
#  'sua',
#  'suas',
#  'também',
#  'te',
#  'tem',
#  'tém',
#  'temos',
#  'tenha',
#  'tenham',
#  'tenhamos',
#  'tenho',
#  'terá',
#  'terão',
#  'terei',
#  'teremos',
#  'teria',
#  'teriam',
#  'teríamos',
#  'teu',
#  'teus',
#  'teve',
#  'tinha',
#  'tinham',
#  'tínhamos',
#  'tive',
#  'tivemos',
#  'tiver',
#  'tivera',
#  'tiveram',
#  'tivéramos',
#  'tiverem',
#  'tivermos',
#  'tivesse',
#  'tivessem',
#  'tivéssemos',
#  'tu',
#  'tua',
#  'tuas',
#  'um',
#  'uma',
#  'você',
#  'vocês',
#  'vos']

# %%
#Criando uma função para retirar as stopwords das frases, já que elas vão ter na frase de medo ou alegria
def removestopwords(text):
    textolimpo = " " # cria uma lista vazia
    doc = text.lower() # Transformando em minúsculo
    separado = doc.split() # transforma em lista de palavras
    for palavra in separado: #vai pegando cada palavra da lista
        if palavra not in stopwordsnltk: # compara cada palavra com a lista de stopwords
          textolimpo += palavra + " " #adiciona cada palavraq que não está nas stopwords na frase
    return textolimpo

# %%
fraseteste = "Eu não sei o porquê, mas amo viajar"

# %%
removestopwords(fraseteste)
# Out:
# ' sei porquê, amo viajar '

# %% [markdown]
# ### aplicando a função na base de dados toda

# %%
frases['frase'] = frases['frase'].apply(removestopwords)
# Out:
# <ipython-input-81-31c157ed447f>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   frases['frase'] = frases['frase'].apply(removestopwords)

# %%
frases
# Out:
#                                        frase
# 446                    recebi elogio chefe.
# 53                       adoro cabelo macio
# 131                                  rainha
# 487            feliz ter terminado projeto.
# 167               lugar continua assustador
# ..                                       ...
# 536        casa vazia noite deixa inquieto.
# 348              ansioso encontrar família.
# 66                                luar belo
# 52                                    adoro
# 289   ouvi passos estranhos corredor noite.
#
# [680 rows x 1 columns]

# %% [markdown]
# ##Separar a base de dados, separando 25% da base para ficar para teste

# %%
from sklearn.model_selection import train_test_split
frases_treino, frases_teste, senti_treino, senti_teste = train_test_split(frases, sentimento, test_size=0.25,shuffle=True)

# %%
frases_treino
# Out:
#                                       frase
# 190                     socorro, vou cair!
# 319     emocionado encontrar melhor amigo.
# 432              casa abandonada sinistra.
# 596   notícias desastre natural preocupam.
# 202     sinto arrepios fico sozinho escuro
# ..                                      ...
# 346     ver filho sorrindo deixa radiante.
# 618   notícias desastre natural preocupam.
# 352              casa abandonada sinistra.
# 121                    elogio nunca demais
# 114              contente aceita faculdade
#
# [510 rows x 1 columns]

# %%
senti_treino
# Out:
# array(['medo', 'alegria', 'medo', 'medo', 'medo', 'alegria', 'medo',
#        'medo', 'alegria', 'alegria', 'alegria', 'alegria', 'medo',
#        'alegria', 'medo', 'medo', 'medo', 'medo', 'medo', 'alegria',
#        'medo', 'alegria', 'medo', 'alegria', 'medo', 'alegria', 'medo',
#        'alegria', 'medo', 'medo', 'medo', 'alegria', 'medo', 'medo',
#        'alegria', 'alegria', 'medo', 'alegria', 'alegria', 'alegria',
#        'medo', 'alegria', 'alegria', 'alegria', 'alegria', 'alegria',
#        'medo', 'alegria', 'alegria', 'alegria', 'medo', 'medo', 'alegria',
#        'medo', 'medo', 'alegria', 'medo', 'alegria', 'alegria', 'alegria',
#        'medo', 'medo', 'alegria', 'medo', 'medo', 'alegria', 'alegria',
#        'medo', 'medo', 'medo', 'medo', 'alegria', 'alegria', 'medo',
#        'alegria', 'alegria', 'medo', 'alegria', 'medo', 'medo', 'alegria',
#        'medo', 'alegria', 'alegria', 'alegria', 'medo', 'medo', 'medo',
#        'alegria', 'alegria', 'alegria', 'alegria', 'medo', 'medo', 'medo',
#        'alegria', 'alegria', 'medo', 'alegria', 'alegria', 'alegria',
#        'alegria', 'medo', 'alegria', 'medo', 'medo', 'alegria', 'alegria',
#        'alegria', 'medo', 'alegria', 'medo', 'alegria', 'alegria',
#        'alegria', 'medo', 'medo', 'medo', 'alegria', 'alegria', 'medo',
#        'medo', 'medo', 'medo', 'alegria', 'alegria', 'alegria', 'alegria',
#        'alegria', 'medo', 'medo', 'alegria', 'alegria', 'alegria',
#        'alegria', 'alegria', 'medo', 'medo', 'medo', 'medo', 'alegria',
#        'alegria', 'medo', 'medo', 'medo', 'alegria', 'medo', 'medo',
#        'alegria', 'alegria', 'alegria', 'medo', 'alegria', 'medo',
#        'alegria', 'medo', 'medo', 'alegria', 'medo', 'alegria', 'medo',
#        'alegria', 'alegria', 'medo', 'medo', 'medo', 'alegria', 'alegria',
#        'medo', 'alegria', 'alegria', 'medo', 'alegria', 'medo', 'medo',
#        'medo', 'medo', 'medo', 'medo', 'alegria', 'alegria', 'medo',
#        'medo', 'medo', 'medo', 'medo', 'alegria', 'alegria', 'alegria',
#        'medo', 'alegria', 'alegria', 'alegria', 'alegria', 'alegria',
#        'alegria', 'medo', 'medo', 'alegria', 'medo', 'medo', 'medo',
#        'alegria', 'alegria', 'medo', 'medo', 'medo', 'medo', 'alegria',
#        'medo', 'alegria', 'medo', 'medo', 'medo', 'medo', 'alegria',
#        'medo', 'medo', 'alegria', 'alegria', 'medo', 'medo', 'medo',
#        'medo', 'alegria', 'medo', 'alegria', 'alegria', 'medo', 'alegria',
#        'alegria', 'alegria', 'alegria', 'medo', 'medo', 'medo', 'alegria',
#        'alegria', 'alegria', 'medo', 'alegria', 'medo', 'alegria', 'medo',
#        'medo', 'medo', 'medo', 'alegria', 'medo', 'alegria', 'alegria',
#        'medo', 'alegria', 'medo', 'medo', 'medo', 'medo', 'medo', 'medo',
#        'alegria', 'alegria', 'medo', 'alegria', 'alegria', 'medo',
#        'alegria', 'alegria', 'alegria', 'alegria', 'medo', 'alegria',
#        'alegria', 'medo', 'alegria', 'medo', 'alegria', 'medo', 'alegria',
#        'medo', 'medo', 'medo', 'medo', 'alegria', 'medo', 'medo', 'medo',
#        'medo', 'medo', 'alegria', 'medo', 'medo', 'medo', 'medo', 'medo',
#        'alegria', 'alegria', 'alegria', 'alegria', 'medo', 'medo',
#        'alegria', 'alegria', 'alegria', 'medo', 'alegria', 'medo', 'medo',
#        'alegria', 'medo', 'alegria', 'medo', 'alegria', 'alegria',
#        'alegria', 'alegria', 'alegria', 'alegria', 'medo', 'medo',
#        'alegria', 'alegria', 'medo', 'medo', 'alegria', 'alegria', 'medo',
#        'alegria', 'alegria', 'alegria', 'alegria', 'medo', 'alegria',
#        'medo', 'alegria', 'alegria', 'medo', 'medo', 'medo', 'medo',
#        'alegria', 'medo', 'alegria', 'alegria', 'alegria', 'alegria',
#        'medo', 'alegria', 'medo', 'alegria', 'alegria', 'medo', 'medo',
#        'alegria', 'medo', 'alegria', 'medo', 'medo', 'medo', 'alegria',
#        'alegria', 'alegria', 'alegria', 'alegria', 'alegria', 'alegria',
#        'alegria', 'alegria', 'medo', 'alegria', 'alegria', 'medo',
#        'alegria', 'medo', 'alegria', 'medo', 'medo', 'alegria', 'alegria',
#        'alegria', 'alegria', 'alegria', 'alegria', 'alegria', 'alegria',
#        'medo', 'medo', 'alegria', 'alegria', 'medo', 'alegria', 'alegria',
#        'medo', 'medo', 'alegria', 'alegria', 'alegria', 'medo', 'medo',
#        'alegria', 'alegria', 'alegria', 'medo', 'alegria', 'medo',
#        'alegria', 'alegria', 'medo', 'medo', 'alegria', 'alegria',
#        'alegria', 'alegria', 'alegria', 'medo', 'medo', 'alegria',
#        'alegria', 'medo', 'medo', 'medo', 'alegria', 'alegria', 'alegria',
#        'medo', 'medo', 'medo', 'medo', 'alegria', 'medo', 'medo',
#        'alegria', 'alegria', 'alegria', 'medo', 'alegria', 'medo', 'medo',
#        'alegria', 'alegria', 'medo', 'medo', 'alegria', 'medo', 'alegria',
#        'medo', 'medo', 'alegria', 'medo', 'medo', 'alegria', 'medo',
#        'medo', 'alegria', 'alegria', 'alegria', 'alegria', 'alegria',
#        'medo', 'alegria', 'alegria', 'alegria', 'medo', 'alegria', 'medo',
#        'alegria', 'medo', 'alegria', 'medo', 'alegria', 'alegria',
#        'alegria', 'medo', 'alegria', 'medo', 'alegria', 'alegria', 'medo',
#        'medo', 'medo', 'medo', 'alegria', 'medo', 'alegria', 'alegria',
#        'alegria', 'alegria', 'alegria', 'medo', 'medo', 'medo', 'medo',
#        'medo', 'alegria', 'alegria', 'alegria', 'medo', 'alegria', 'medo',
#        'alegria', 'medo', 'medo', 'alegria', 'alegria', 'alegria', 'medo',
#        'alegria', 'medo', 'medo', 'alegria', 'alegria'], dtype=object)

# %%
#essas vou usar para ensinar a IA
frases_treino.shape
# Out:
# (510, 1)

# %%
senti_treino.shape
# Out:
# (510,)

# %%
# com essas vou ver se ela aprendeu
frases_teste.shape
# Out:
# (170, 1)

# %% [markdown]
# ## Agora que nossa base está separada vamos converter nossos textos em números para a Inteligência Artificial. Processo de Vetorização de Palavras

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
vocab = basenova['frase'].values

# %%
vocab
# Out:
# array(['Recebi um elogio do meu chefe.', 'adoro seu cabelo macio',
#        'eu sou sua rainha ', 'Estou feliz por ter terminado meu projeto.',
#        'este lugar continua assustador',
#        'tomara que eles não me vejam daqui!',
#        'O nascer do sol nas montanhas é incrível.',
#        'eu te entrego o dinheiro, por favor não me mate!',
#        'Encontrei uma nota antiga de amor e fiquei emocionado.',
#        'desejo a você tudo de bom', 'eu serei sua amiga e companheira',
#        'somos compatíveis um com o outro',
#        'A notícia de que a família está vindo me alegra.',
#        'Recebi um e-mail ameaçador.', 'o amor e abundante',
#        'Estou animado para conhecer novas pessoas.',
#        'Recebi uma carta de agradecimento inesperada.',
#        'O nascer do sol na montanha é deslumbrante.',
#        'eu adorei este perfume', 'não tive culpa, juro não fui eu',
#        'seu amor e brilhante',
#        'O filme de terror me deu pesadelos à noite.',
#        'Meu time esportivo favorito ganhou o jogo.',
#        'As notícias de um desastre natural me preocupam.',
#        'Recebi uma mensagem ameaçadora no meu e-mail.',
#        'Estou feliz por ter terminado meu projeto.',
#        'Assistir a um filme engraçado me deixa alegre.',
#        'Meu time esportivo favorito está indo para as finais.',
#        'Um vulto misterioso apareceu na foto.',
#        'A tempestade está ficando mais forte.',
#        'não tenho certeza se e seguro',
#        'Vi algo sinistro no canto do meu olho.',
#        'nossa como sou afortunado',
#        'Estou emocionado por ser surpreendido com uma festa.',
#        'O nascer do sol nas montanhas é incrível.',
#        'estou tremendo de medo!',
#        'Vi algo sinistro no canto do meu olho.',
#        'Comemorei meu aniversário com um bolo delicioso.',
#        'Estou radiante com o nascimento do meu sobrinho!',
#        'sou muito grata a você', 'não me preocupo com o que aconteceu',
#        'eu não confio nele, tenho que ter cautela',
#        'Ficar sozinho em uma casa vazia é assustador.',
#        'Fui aceito na universidade que eu sempre quis.',
#        'O cheiro de bolo assando enche a casa de alegria.',
#        'Aquela casa abandonada é sinistra.',
#        'Ouvi um barulho estranho no porão à noite.',
#        'vou ficar sem mesada se tirar nota baixa',
#        'meu plano pode ser descoberto',
#        'A tempestade está ficando mais forte.',
#        'eu não vou ate a floresta negra, e muito perigoso',
#        'Meu time esportivo favorito ganhou o jogo.',
#        'Meu time marcou um gol no último minuto.',
#        'Recebi uma carta de amor surpresa.',
#        'Meu time esportivo favorito ganhou o jogo.',
#        'A notícia de que a família está vindo me alegra.',
#        'sou muito afortunado',
#        'Comemorei meu aniversário com uma festa surpresa.',
#        'estou correndo riscos de saúde', 'que abominável esse montro!',
#        'não confio em você', 'Recebi um abraço caloroso de um amigo.',
#        'calma, eu não estou com o dinheiro',
#        'isso não e remedio, não me matem',
#        'Ouvi sussurros inquietantes no corredor.',
#        'Meu time esportivo favorito está indo para as finais.',
#        'As notícias de um novo vírus são aterrorizantes.',
#        'Meu livro favorito foi adaptado para um filme.',
#        'Consegui um novo emprego com um salário incrível!',
#        'concretizamos nossa ideia',
#        'Estou contente por passar tempo com meus avós.',
#        'estamos muito felizes juntos',
#        'A notícia de um crime na minha vizinhança é perturbadora.',
#        'Recebi uma proposta de emprego dos meus sonhos.',
#        'A surpresa do meu amigo me deixou muito feliz.',
#        'As crianças brincando no parque me fazem sorrir.',
#        'Vi uma figura assustadora na floresta.',
#        'a dor esta amenizando finalmente', 'que roupa delicada',
#        'Ganhei um prêmio de fotografia.',
#        'graças a deus que eu enxerguei o certo',
#        'eu sou admirada por muitos', 'temo pela sua segurança',
#        'Um ruído no meio da noite me perturba.',
#        'A escuridão na floresta me deixa apreensivo.',
#        'Comemorei meu aniversário com pessoas queridas.',
#        'Estou emocionado por ser surpreendido com uma festa.',
#        'Recebi uma carta de agradecimento inesperada.',
#        'Ver meu filho sorrindo me deixa radiante.',
#        'Recebi uma ligação misteriosa no meio da noite.',
#        'Encontrei meu amigo depois de muito tempo e estou alegre.',
#        'A escuridão na floresta me deixa apreensivo.',
#        'Ouvi um barulho estranho no sótão à noite.',
#        'Estou animado para conhecer novas pessoas.', 'sinto-me viva ',
#        'afugente os cães', 'vou me afogar, me ajudem a sair da água',
#        'não tenho certeza se e seguro',
#        'O filme de terror me deixa com medo.',
#        'poderemos completar o projeto hoje!',
#        'Encontrei uma nota antiga de amor e fiquei emocionado.',
#        'Meu time esportivo favorito está indo para as finais.',
#        'Estou radiante com o nascimento do meu sobrinho!',
#        'você esta me apavorando', 'estou ansiosa pela sua chegada',
#        'Estou contente por passar tempo com meus avós.',
#        'A escuridão na floresta me deixa apreensivo.',
#        'ótimo e compatível', 'você e como um sonho doce',
#        'fui aprovada no meu exame',
#        'estou namorando este vestido a um tempo',
#        'A figura na janela me dá arrepios.',
#        'Apareceu um vulto no espelho do banheiro.',
#        'O cheiro de bolo assando enche a casa de alegria.',
#        'Assistir ao pôr do sol na praia é incrível.',
#        'esse cara está me perseguindo',
#        'estou com dificuldades para respirar e muito assustado',
#        'ele e realmente fiel a mim',
#        'o órgão e compatível com o paciente',
#        'este lugar está silencioso de mais, cuidado!',
#        'com o consentimento dos meus pais podemos nos casar',
#        'pude comprar meu celular hoje',
#        'Vi algo se mover no canto do meu olho e me assustou.',
#        'socorro! ele queria roubar os meus doces!',
#        'A notícia de que a família está vindo me alegra.',
#        'Vi algo se mover no canto do meu olho e me assustou.',
#        'O filme de terror me deixa com medo.',
#        'estou desconfiada de você',
#        'O cheiro de bolo assando enche a casa de alegria.',
#        'Recebi uma mensagem de ameaça nas redes sociais.',
#        'Meu time marcou um gol no último minuto.',
#        'Recebi uma mensagem de amor inesperada.',
#        'A notícia de um novo vírus me deixa apreensivo.',
#        'Recebi um presente especial de aniversário.',
#        'eu nunca tive duvidas', 'estou ouvindo passos atrás de mim',
#        'estou completamente apaixonada ', 'estou aproveitando as ferias',
#        'Algo se moveu no armário e me assustou.',
#        'Recebi uma mensagem ameaçadora no meu e-mail.',
#        'Vi algo se mover no canto do meu olho e me assustou.',
#        'parece que tem olhos nos vigiando',
#        'Percebi sombras se movendo na sala.',
#        'O filme de terror me deixa com medo.',
#        'e bom estar quente neste frio',
#        'Meu time esportivo favorito ganhou o jogo.',
#        'Ficar sozinho em uma casa vazia é assustador.',
#        'por favor, me soltem, eu sou inocente',
#        'Ganhei um dia de spa como presente e estou feliz.',
#        'Recebi elogios pelo meu trabalho hoje.',
#        'e desejável a sua presença em nossa apresentação',
#        'As notícias sobre um vírus desconhecido são assustadoras.',
#        'Recebi uma mensagem de amor inesperada.',
#        'Estou radiante com o nascimento do meu sobrinho!',
#        'esta comida me parece muito atraente',
#        'Recebi uma ligação de um número desconhecido.',
#        'Aquela casa abandonada é sinistra.',
#        'a arrumação esta terminada, que alívio',
#        'A tempestade está se aproximando rapidamente.',
#        'tire isso de mim! socorro!', 'Recebi um elogio do meu chefe.',
#        'Meu time marcou um gol no último minuto.',
#        'me advertiram sobre isso', 'Meu restaurante favorito reabriu.',
#        'Ficar sozinho em uma casa abandonada é aterrorizante.',
#        'estou assombrado pela crise financeira',
#        'As notícias de um desastre natural me preocupam.',
#        'agradeço imensamente o seu apoio nestes dias',
#        'O nascer do sol na montanha é deslumbrante.',
#        'As crianças brincando no parque me fazem sorrir.',
#        'Os relatos de atividade paranormal são assustadores.',
#        'Recebi elogios pelo meu trabalho hoje.',
#        'um chá quente e reconfortante',
#        'Aquela sombra na parede me deixa com medo.',
#        'espere, não pode me largar aqui sozinho',
#        'muito bem esta tudo em ordem agora ',
#        'olha aquela criatura se movendo monstruosamente',
#        'Um vulto misterioso apareceu na foto.',
#        'O filme de terror me deixou tenso e nervoso.',
#        'Estou feliz por ter terminado meu projeto.',
#        'e benefico para todos esta nova medida',
#        'isso me deixa apavorada', 'A figura na janela me dá arrepios.',
#        'Estou animado para conhecer novas pessoas.',
#        'O filme de terror me deu pesadelos à noite.',
#        'Estou ansioso para encontrar minha família.',
#        'As notícias sobre crimes violentos me preocupam.',
#        'concretizei finalmente meu sonho',
#        'Um grito ecoou no silêncio da noite.',
#        'os tubarões estão atacando!', 'e muito bom estar com os amigos',
#        'estou estremecendo com essa casa',
#        'A montanha-russa me deixou emocionado.',
#        'agora se sente humilhado, apavorado',
#        'Ouvi passos estranhos no corredor à noite.',
#        'Recebi uma carta de agradecimento emocionante.',
#        'temos água em abundancia',
#        'Ganhei um dia de spa como presente e estou feliz.',
#        'meu suco favorito',
#        'As notícias de um desastre natural me preocupam.',
#        'Recebi uma ligação de um número desconhecido.',
#        'A surpresa de aniversário foi inesquecível.',
#        'alguem esta me ligando, estou assustado',
#        'Ouvir um barulho estranho me assusta.',
#        'Assistir a um filme engraçado me deixa alegre.',
#        'me sinto flutuando no ar',
#        'o trabalhador e assombrado pelo temor do desemprego',
#        'Encontrei uma nota antiga de amor e fiquei emocionado.',
#        'isso me apavora', 'tenho medo de ser advertida novamente',
#        'A surpresa de aniversário foi inesquecível.',
#        'Recebi uma mensagem de texto adorável.',
#        'tem certeza que não e perigoso?',
#        'A figura na janela me dá arrepios.',
#        'Percebi sombras se movendo na sala.',
#        'congratulações pelo seu aniversário',
#        'A casa vazia à noite me deixa inquieto.',
#        'estou sem saída, preciso de um milagre',
#        'ele esta me ameaçando a dias',
#        'Encontrei uma nota antiga de amor e fiquei emocionado.',
#        'Estou animado com as férias planejadas.',
#        'não sei nadar, vou me afogar!', 'fiz a adesão ao curso hoje',
#        'e emocionante estar neste lugar',
#        'Recebi uma mensagem de ameaça nas redes sociais.',
#        'estou assustado com as ações do meu colega',
#        'Ganhei um sorteio e estou radiante!',
#        'Estou contente por passar tempo com meus avós.',
#        'que bondade a sua em vir aqui',
#        'O filme de terror me deixa com medo.', 'ficou lindo',
#        'a musica e linda', 'O filme de terror me deixa com medo.',
#        'Ouvi um ruído estranho no sótão.',
#        'Meu livro favorito foi adaptado para um filme.',
#        'As notícias de um desastre natural me preocupam.',
#        'Fiz uma viagem inesperada e estou radiante.',
#        'Um vulto misterioso apareceu na foto.', 'estamos namorando',
#        'Estou radiante com o nascimento do meu sobrinho!',
#        'A tempestade está se aproximando rapidamente.',
#        'Recebi uma ligação misteriosa no meio da noite.',
#        'eu acho que estou sendo enganado',
#        'Recebi um abraço caloroso de um amigo.',
#        'Estou feliz por encontrar meu amigo depois de tanto tempo.',
#        'vamos ser caridosos este natal',
#        'O filme de terror me deu arrepios.',
#        'o mais incrível e você minha bela',
#        'A figura na janela me dá arrepios.',
#        'Recebi uma carta de agradecimento inesperada.',
#        'Ouvi passos estranhos no corredor à noite.',
#        'Recebi uma mensagem de texto adorável.',
#        'Recebi uma ligação de um número desconhecido.',
#        'que grande alivio', 'e muito divertido este jogo',
#        'me dedico muito naquilo que faço',
#        'Algo se moveu no armário e me assustou.',
#        'Estou feliz por ter tempo para minhas paixões.',
#        'Percebi sombras se movendo na sala.',
#        'Ficar sozinho no escuro é assustador.',
#        'não sei não, parece perigoso',
#        'O filme de terror me deu pesadelos à noite.',
#        'me sinto muito bem hoje', 'socorro, fui intimado a depor',
#        'Estou feliz por encontrar meu amigo depois de tanto tempo.',
#        'o dia esta muito bonito',
#        'e um deleite poder compartilhar minhas vitórias',
#        'Recebi um e-mail ameaçador.',
#        'Assistir ao pôr do sol na praia é maravilhoso.',
#        'Ouvi sussurros inquietantes no corredor.',
#        'estou contente com o apoio', 'sua bondade e cativante',
#        'Recebi uma mensagem de amor inesperada.',
#        'não quero nem pensar no que pode acontecer',
#        'Aquela casa abandonada é sinistra.',
#        'Vi uma figura assustadora na floresta.',
#        'ouço passos na minha direção',
#        'Um ruído no meio da noite me perturba.', 'amar e maravilhoso',
#        'Recebi um elogio do meu chefe.',
#        'Recebi uma ligação com uma voz assustadora.',
#        'finalmente completei a minha coleção, maravilhoso',
#        'Estou emocionado por encontrar meu melhor amigo.',
#        'Vi algo sinistro no canto do meu olho.',
#        'vou te chamar para comemorar',
#        'Meu time esportivo favorito está indo para as finais.',
#        'Ouvi um barulho estranho no porão à noite.',
#        'estou comovido com tamanha caridade',
#        'me descobriram, irão me prender!',
#        'na selva tem muitos animais perigosos',
#        'Recebi uma mensagem assustadora de um número desconhecido.',
#        'Encontrei meu amigo depois de muito tempo e estou alegre.',
#        'Estou animado com as férias planejadas.',
#        'A surpresa de aniversário foi inesquecível.',
#        'Ouvir um barulho estranho me assusta.',
#        'A escuridão na floresta me deixa apreensivo.',
#        'Ficar sozinho em uma casa escura é assustador.',
#        'conclui minha graduação', 'o amor e lindo',
#        'A festa de aniversário foi um sucesso!', 'estou angustiada',
#        'Aquela casa antiga é assustadora à noite.',
#        'sem musica eu não vivo',
#        'A surpresa de aniversário foi inesquecível.',
#        'seu políticos usam suas forças para afugentar e amedrontar o povo',
#        'O barulho da tempestade me deixa assustado.',
#        'Estou ansioso para encontrar minha família.',
#        'Recebi uma carta de agradecimento emocionante.', 'muita cautela',
#        'aterrorizado e suando frio',
#        'A tempestade está se aproximando rapidamente.',
#        'Recebi um abraço caloroso de um amigo.',
#        'Comemorei meu aniversário com um bolo delicioso.',
#        'O cheiro de bolo assando enche a casa de alegria.',
#        'Estou radiante com o nascimento do meu filho.',
#        'Comemorei meu aniversário com uma festa surpresa.',
#        'a brisa esta agradável hoje',
#        'Ouvi passos no corredor vazio à noite.',
#        'que alegria ter vocês aqui ',
#        'Aquela sombra na janela me deixa apreensivo.',
#        'foi terrível o tigre quase o matou',
#        'A surpresa do meu amigo me deixou muito feliz.',
#        'estou loucamente apaixonada',
#        'tenho que correr pra não me pegarem',
#        'Ouvi um barulho estranho no porão à noite.',
#        'Aquela sombra na janela me deixa apavorado.',
#        'não entro lá, e um lugar muito perigoso',
#        'O barulho do trovão me deixa apavorado.',
#        'e preciso afugenta com ímpeto este medo do inferno',
#        'fuja! o tigre parece faminto',
#        'Fiz uma viagem inesperada e estou radiante.',
#        'Ficar sozinho no escuro é assustador.',
#        'Meu restaurante favorito reabriu.',
#        'A escuridão na floresta me deixa apreensivo.',
#        'Recebi um presente especial de aniversário.',
#        'Aquela sombra na janela me deixa apreensivo.',
#        'Ouvi passos estranhos no corredor à noite.',
#        'um grupo de elefantes selvagens tem aterrorizado vilas',
#        'você será muito amado meu filho',
#        'mantenha isso em segredo, se descobrirem estaremos ferrados',
#        'vamos voltar, e muito perigoso',
#        'sinto arrepios quando fico sozinho no escuro',
#        'O nascer do sol nas montanhas é incrível.',
#        'A notícia de que meu amigo está se recuperando é uma alegria.',
#        'Ouvir um barulho estranho me assusta.', 'eu amo você',
#        'Estou animado para conhecer novas pessoas.',
#        'O nascer do sol nas montanhas é incrível.',
#        'podemos arrumar um emprego juntos ',
#        'Aquela casa abandonada é sinistra.',
#        'eu estou sorrindo de orelha a orelha',
#        'Assistir a um filme engraçado me deixa alegre.',
#        'ele vai levar todo o meu dinheiro',
#        'Recebi uma mensagem de texto adorável.',
#        'estou rodeada pelo seu abraço',
#        'O filme de terror me deixou tenso e nervoso.',
#        'Um ruído no meio da noite me perturba.',
#        'Comemorei meu aniversário com um bolo delicioso.',
#        'sinto-me em paz ',
#        'Recebi uma mensagem assustadora de um número desconhecido.',
#        'ate o cachorro está apavorado',
#        'Ficar sozinho em uma casa escura é assustador.',
#        'Consegui meu diploma com honras!',
#        'vamos agir sem preconceitos e julgamentos',
#        'nossa amizade vai durar para sempre', 'e um prazer conhecê-lo',
#        'palmas para a aniversariante',
#        'vou apanhar se meus pais verem meu boletim',
#        'A tempestade está se aproximando rapidamente.',
#        'Ouvi um barulho estranho no porão à noite.',
#        'estou eufórica com a noticia', 'este lugar e mal assombrado',
#        'estou tão animada com os preparativos para o casamento',
#        'A notícia de um crime na minha vizinhança é perturbadora.',
#        'Ouvi um barulho estranho no porão à noite.',
#        'Ouvi sussurros inquietantes no corredor.',
#        'e abominável o que fazem com os animais',
#        'Ficar sozinho em uma casa vazia é assustador.',
#        'quero agradar meus filhos',
#        'O casamento dos meus melhores amigos foi emocionante.',
#        'Vi algo sinistro no canto do meu olho.',
#        'Recebi uma mensagem ameaçadora no meu e-mail.',
#        'As notícias sobre crimes violentos me preocupam.',
#        'O nascer do sol nas montanhas é incrível.',
#        'Estou ansioso para encontrar minha família.',
#        'O filme de terror me deu pesadelos à noite.',
#        'eu temo que a sentença do juiz possa ser negativa',
#        'O filme de terror me deixa com medo.',
#        'essa e a melhor escolhas de todas',
#        'Recebi uma mensagem de ameaça nas redes sociais.',
#        'Algo se moveu no armário e me assustou.',
#        'Recebi elogios pelo meu trabalho hoje.',
#        'essa pintura esta bem brilhante',
#        'Aquela casa abandonada é sinistra.',
#        'As notícias de um desastre natural me preocupam.',
#        'Ouvi passos no corredor vazio à noite.',
#        'Assistir ao pôr do sol na praia é maravilhoso.',
#        'Um ruído no meio da noite me perturba.',
#        'o coleguismo de vocês e animador', 'sou querida pelos meu amigos',
#        'Meu time marcou um gol no último minuto.',
#        'Vi algo se mover no canto do meu olho e me assustou.',
#        'este trabalho e agradável', 'somo tão amáveis um com o outro',
#        'eu sinto o sol sempre que você esta por perto',
#        'Assistir a um filme engraçado me deixa alegre.',
#        'Assistir ao pôr do sol na praia é maravilhoso.',
#        'mesmo aterrorizado lembro de você',
#        'A tempestade está se aproximando rapidamente.',
#        'Recebi uma mensagem de ameaça nas redes sociais.',
#        'Meu livro foi publicado e estou radiante!', 'o câncer e benigno ',
#        'socorro! ele está armado!', 'gosto de ficar no seu aconchego',
#        'me sinto intimidada pela sua presença',
#        'fui notificado e estou com medo de perde a guarda da minha filha',
#        'Recebi uma ligação misteriosa no meio da noite.',
#        'As notícias sobre crimes violentos me preocupam.',
#        'Recebi um abraço caloroso de um amigo.',
#        'o objetivo disso e apenas me amedrontar mais',
#        'maravilhoso jogo amistoso',
#        'Ficar sozinho em uma casa vazia é assustador.',
#        'e serio, cuidado com essa arma!', 'mas essa missão e arriscada',
#        'assustou a população e provocou mortes',
#        'satisfatoriamente eu anuncio o vencedor dos jogos',
#        'Meu livro favorito foi adaptado para um filme.',
#        'socorro, eu vou cair!',
#        'Aquela sombra na janela me deixa apreensivo.',
#        'Recebi um e-mail ameaçador.', 'a noite e muito perigosa',
#        'por favor, deixe-me viver!',
#        'As notícias sobre crimes violentos me preocupam.',
#        'angustiadamente vou sair e casa', 'estamos tendo muito lucro',
#        'nessa cidade e uma desgraça atrás da outra',
#        'A surpresa de aniversário foi inesquecível.',
#        'aquele rapaz e extremamente atraente',
#        'Ouvi passos no corredor vazio à noite.',
#        'Um vulto misterioso apareceu na foto.',
#        'ligeiro, temos que fugir depressa',
#        'A notícia de que meu amigo está se recuperando é uma alegria.',
#        'se sair tão tarde, poderei ser assaltada',
#        'A notícia de um novo vírus me deixa apreensivo.',
#        'eu sou muito cativante', 'as maravilhas do mundo',
#        'Estou animado com as férias planejadas.',
#        'fui beneficiada pela minha empresa',
#        'As notícias de um desastre natural me preocupam.',
#        'Ouvi passos estranhos no corredor à noite.',
#        'vamos aproveitar as ferias',
#        'Ouvi passos no corredor vazio à noite.',
#        'Estou emocionado por ser surpreendido com uma festa.',
#        'A notícia de um crime na minha vizinhança é perturbadora.',
#        'Estou emocionado por ser surpreendido com uma festa.',
#        'A casa vazia à noite me deixa inquieto.',
#        'estou chocado e amedrontado com este assassinato brutal',
#        'As crianças brincando no parque me fazem sorrir.',
#        'só espero que não me façam nenhum mal',
#        'estou muito contente com o resultado dos testes',
#        'O filme de terror me deixa com medo.',
#        'achei esse sapato muito simpático',
#        'Estou feliz por ter terminado meu projeto.',
#        'Algo se moveu no armário e me assustou.',
#        'Recebi um abraço caloroso de um amigo.',
#        'O filme de terror me deixou tenso e nervoso.',
#        'não achei que me divertiria tanto assim',
#        'O barulho do trovão me deixa apavorado.',
#        'Ganhei um prêmio inesperado hoje!',
#        'finalmente você colocou meu amor em primeiro lugar',
#        'Meu time esportivo favorito ganhou o jogo.',
#        'A floresta à noite me dá arrepios.',
#        'Aquela sombra na janela me deixa apreensivo.',
#        'Estou feliz por ter tempo para minhas paixões.',
#        'Algo se moveu no armário e me assustou.',
#        'Ouvi sussurros inquietantes no corredor.',
#        'conclui uma tarefa muito difícil',
#        'Ganhei um sorteio e estou radiante!',
#        'podemos perder muito dinheiro com essa investida',
#        'delicadamente ele a colocou para dormir',
#        'me sinto completamente amado',
#        'Recebi elogios pelo meu trabalho hoje.',
#        'vamos aplaudir o vencedor ',
#        'Estou feliz por ter tempo para minha família.',
#        'Ficar sozinho em uma casa escura é assustador.',
#        'Aquela sombra na parede me deixa com medo.',
#        'As crianças brincando no parque me fazem sorrir.',
#        'vou consentir o orçamento ao cliente',
#        'Recebi uma mensagem de amor inesperada.',
#        'nossa como você e charmoso querido ',
#        'Estou feliz por ter tempo para minhas paixões.',
#        'A notícia de que meu amigo está se recuperando é uma alegria.',
#        'Recebi uma ligação de um número desconhecido.',
#        'Aquela sombra na parede me deixa com medo.',
#        'Recebi uma carta de agradecimento emocionante.',
#        'nós dançamos noite adentro',
#        'Ganhei um sorteio e estou radiante!',
#        'vou dar uma grande festa para comemorar meu aniversário',
#        'Fiz uma viagem inesperada e estou radiante.',
#        'vou ser descoberto, meu deus', 'sinto uma grande afeição por ele',
#        'estou amedrontada', 'socorro, nós estamos afundando',
#        'Ver meu filho sorrindo me deixa radiante.',
#        'A música me faz sorrir todos os dias.',
#        'cuidado com as curvas na estrada',
#        'A surpresa do meu amigo me deixou muito feliz.',
#        'A surpresa de aniversário me deixou extremamente feliz.',
#        'Recebi um elogio do meu chefe.',
#        'Ganhei um sorteio e estou radiante!',
#        'Ganhei um dia de spa como presente e estou feliz.',
#        'A notícia de um desastre natural me deixa apreensivo.',
#        'A notícia de um novo vírus me deixa apreensivo.',
#        'Recebi um e-mail ameaçador.',
#        'Estou feliz por ter tempo para minhas paixões.',
#        'receio por não me livrar desta situação',
#        'recebi muito carinho hoje do meus colegas',
#        'não agüento este suspense',
#        'Ficar sozinho em uma casa vazia é assustador.',
#        'aprecio sua presença em minha escola',
#        'estou correndo o risco de ser advertido', 'salvem-se quem puder!',
#        'Recebi um presente especial de aniversário.',
#        'fuja, se não acabaremos mortos', 'Meu time venceu o campeonato!',
#        'Ver meu filho sorrindo me deixa radiante.',
#        'Vi uma figura assustadora na floresta.', 'os riscos são reais',
#        'Recebi uma mensagem ameaçadora no meu e-mail.',
#        'O barulho do trovão me deixa apavorado.',
#        'eu imploro, não me matem!',
#        'Vi algo sinistro no canto do meu olho.',
#        'O quarto escuro me deixa com medo.',
#        'trabalhar em equipe e o melhor',
#        'Recebi uma ligação de um número desconhecido.',
#        'Recebi um presente especial de aniversário.',
#        'receio que terei de ir',
#        'O filme de terror me deixou tenso e nervoso.',
#        'avancem com cautela',
#        'A notícia de um novo vírus me deixa apreensivo.',
#        'e ótimo que os ânimos tenham se apaziguado',
#        'toquei muitos corações durante o meu caminho',
#        'eu vou pedir socorro!', 'Percebi sombras se movendo na sala.',
#        'Ganhei um sorteio e estou radiante!',
#        'A figura na janela me dá arrepios.',
#        'O filme de terror me deu pesadelos.',
#        'Ver meu filho sorrindo me deixa radiante.', 'estou despreocupada',
#        'Um estranho se aproximou de mim no beco escuro.',
#        'Ficar sozinho em uma casa escura é assustador.',
#        'anseio por seus próximos trabalhos',
#        'Comi meu bolo de chocolate favorito hoje.',
#        'Ver meu filho sorrindo me deixa radiante.',
#        'Aquela sombra na parede me deixa com medo.',
#        'nosso ideal foi alcançado', 'os apaixonados são maravilhosos',
#        'somos estimados por nossa família',
#        'Ficar sozinho no escuro é assustador.',
#        'Ouvi um ruído estranho no sótão.',
#        'Ficar sozinho no escuro é assustador.',
#        'Um vulto misterioso apareceu na foto.',
#        'Estou contente por passar tempo com meus avós.',
#        'estou me sentindo reconfortada hoje', 'ela e um boa garota',
#        'se ficarmos quietos eles não vão nos achar',
#        'estou cativada pelo seu olhar',
#        'Vi algo se mover no canto do meu olho e me assustou.',
#        'vamos alarmar a todos sobre a situação',
#        'Encontrei meu cachorro perdido depois de dias de busca!',
#        'Assistir a um filme engraçado me deixa alegre.',
#        'Estou animado com as férias planejadas.',
#        'Recebi uma mensagem de texto adorável.',
#        'estou me sentindo muito animada',
#        'Estou feliz por encontrar meu amigo depois de tanto tempo.',
#        'Ouvi um ruído estranho no sótão.',
#        'O nascer do sol na montanha é deslumbrante.',
#        'Estou ansioso para encontrar minha família.',
#        'estou agradecida pela ajuda', 'estivemos em um ótimo show',
#        'acho que me apaixonei', 'eu confio em você',
#        'Perdi meu celular e estou com medo dos meus dados.',
#        'como este lugar e confortável',
#        'Meu livro favorito foi adaptado para um filme.',
#        'estou contente fui aceita na faculdade',
#        'vamos agitar essa noite ', 'não dirija tão rápido assim',
#        'vamos ter muita diversão',
#        'Ouvir um barulho estranho me assusta.',
#        'Ficar sozinho no escuro é assustador.',
#        'se eu ajeitar tudo fica bem',
#        'Recebi uma carta de agradecimento inesperada.',
#        'estou angustiada com meus filhos na rua',
#        'eu vejo estrelas pelo caminho',
#        'Estou feliz por ter terminado meu projeto.',
#        'Meu restaurante favorito reabriu.',
#        'As notícias sobre crimes violentos me preocupam.',
#        'com todo esse charme você irá atrair a todos',
#        'A notícia de que meu amigo está se recuperando é uma alegria.',
#        'seja cuidadoso com os meus sentimentos',
#        'O nascer do sol na montanha é deslumbrante.',
#        'As crianças brincando no parque me fazem sorrir.',
#        'você e um grande comediante', 'estou com muito medo da noite',
#        'Meu restaurante favorito reabriu.',
#        'A surpresa do meu amigo me deixou muito feliz.',
#        'Recebi uma mensagem assustadora de um número desconhecido.',
#        'e um enorme prazer ter você em nossa equipe',
#        'meu deus, ele desapareceu!',
#        'A notícia de um crime na minha vizinhança é perturbadora.',
#        'Recebi uma mensagem ameaçadora no meu e-mail.',
#        'adoro este doce de frutas',
#        'tem um crocodilo selvagem vindo para cá',
#        'Ouvir um barulho estranho me assusta.',
#        'Comemorei meu aniversário com uma festa surpresa.',
#        'estou muito contente com tudo',
#        'O filme de terror me deu pesadelos à noite.',
#        'tenho que tomar cuidado com o lobisomem',
#        'não estaremos a salvo aqui', 'não consigo sair daqui!',
#        'ei cuidado, você vai bater no poste!',
#        'Recebi uma mensagem assustadora de um número desconhecido.',
#        'Recebi elogios pelo meu trabalho hoje.',
#        'Encontrei uma nota antiga de amor e fiquei emocionado.',
#        'hora de apreciar um bom vinho',
#        'se eu não achar, ele vai descobrir a verdade',
#        'Fiz uma viagem inesperada e estou radiante.',
#        'Encontrei meu amigo depois de muito tempo e estou alegre.',
#        'A tempestade está ficando mais forte.',
#        'adoro a cor dos seus olhos',
#        'Ouvi sussurros inquietantes no corredor.',
#        'Assistir ao pôr do sol na praia é maravilhoso.',
#        'Recebi uma mensagem adorável de um ente querido.',
#        'você me completa', 'estimo muito o seu trabalho',
#        'Recebi uma ameaça anônima por telefone.',
#        'A notícia de que a família está vindo me alegra.',
#        'Estou feliz por encontrar meu amigo depois de tanto tempo.',
#        'um elogio nunca e demais',
#        'A viagem para a praia foi relaxante e alegre.',
#        'Um ruído no meio da noite me perturba.',
#        'As notícias de um desastre natural me preocupam.',
#        'isso vale a pena',
#        'As notícias de um desastre natural me preocupam.',
#        'e tão engraçado tentar explicar',
#        'Recebi uma carta de agradecimento inesperada.',
#        'Recebi uma ligação misteriosa no meio da noite.',
#        'não me deixe por favor!', 'me sinto completamente segura',
#        'O cheiro de bolo assando enche a casa de alegria.',
#        'O barulho do trovão me deixa apavorado.',
#        'você me traz de volta a vida',
#        'Aquela sombra na parede me deixa com medo.',
#        'acho que está arriscado de mais',
#        'Recebi uma carta de agradecimento emocionante.',
#        'quanta angustia', 'A tempestade está ficando mais forte.',
#        'A notícia de que meu amigo está se recuperando é uma alegria.',
#        'Ouvi um ruído estranho no sótão.',
#        'Encontrei meu amigo depois de muito tempo e estou alegre.',
#        'minha fortuna ultrapassa a sua',
#        'Comemorei meu aniversário com uma festa surpresa.',
#        'Vi uma figura assustadora na floresta.',
#        'A tempestade está ficando mais forte.',
#        'O filme de terror me deixou tenso e nervoso.',
#        'A notícia de que a família está vindo me alegra.',
#        'Estou animado com as férias planejadas.',
#        'Ganhei um dia de spa como presente e estou feliz.',
#        'você significa muito para mim',
#        'Comemorei meu aniversário com um bolo delicioso.',
#        'os policiais se assustaram quando o carro capotou',
#        'A casa vazia à noite me deixa inquieto.',
#        'você me atrai facilmente ', 'não precisei pagar o ingresso',
#        'A casa vazia à noite me deixa inquieto.',
#        'Estou ansioso para encontrar minha família.',
#        'como o luar e belo', 'adoro como você e',
#        'Ouvi passos estranhos no corredor à noite.'], dtype=object)

# %%
vectorizer = CountVectorizer()
vectorizer.fit_transform(vocab)
vectorizer.get_feature_names_out()
# Out:
# array(['abandonada', 'abominável', 'abraço', 'abundancia', 'abundante',
#        'acabaremos', 'aceita', 'aceito', 'achar', 'achei', 'acho',
#        'aconchego', 'acontecer', 'aconteceu', 'adaptado', 'adentro',
#        'adesão', 'admirada', 'adorei', 'adoro', 'adorável', 'advertida',
#        'advertido', 'advertiram', 'afeição', 'afogar', 'afortunado',
#        'afugenta', 'afugentar', 'afugente', 'afundando', 'agir', 'agitar',
#        'agora', 'agradar', 'agradecida', 'agradecimento', 'agradeço',
#        'agradável', 'agüento', 'ajeitar', 'ajuda', 'ajudem', 'alarmar',
#        'alcançado', 'alegra', 'alegre', 'alegria', 'algo', 'alguem',
#        'alivio', 'alívio', 'amado', 'amar', 'ameaça', 'ameaçador',
#        'ameaçadora', 'ameaçando', 'amedrontada', 'amedrontado',
#        'amedrontar', 'amenizando', 'amiga', 'amigo', 'amigos', 'amistoso',
#        'amizade', 'amo', 'amor', 'amáveis', 'angustia', 'angustiada',
#        'angustiadamente', 'animada', 'animado', 'animador', 'animais',
#        'aniversariante', 'aniversário', 'anseio', 'ansiosa', 'ansioso',
#        'antiga', 'anuncio', 'anônima', 'ao', 'apaixonada', 'apaixonados',
#        'apaixonei', 'apanhar', 'apareceu', 'apavora', 'apavorada',
#        'apavorado', 'apavorando', 'apaziguado', 'apenas', 'aplaudir',
#        'apoio', 'apreciar', 'aprecio', 'apreensivo', 'apresentação',
#        'aprovada', 'aproveitando', 'aproveitar', 'aproximando',
#        'aproximou', 'aquela', 'aquele', 'aqui', 'ar', 'arma', 'armado',
#        'armário', 'arrepios', 'arriscada', 'arriscado', 'arrumar',
#        'arrumação', 'as', 'assaltada', 'assando', 'assassinato', 'assim',
#        'assistir', 'assombrado', 'assusta', 'assustado', 'assustador',
#        'assustadora', 'assustadoras', 'assustadores', 'assustaram',
#        'assustou', 'atacando', 'ate', 'aterrorizado', 'aterrorizante',
#        'aterrorizantes', 'atividade', 'atraente', 'atrai', 'atrair',
#        'atrás', 'avancem', 'avós', 'ações', 'baixa', 'banheiro',
#        'barulho', 'bater', 'beco', 'bela', 'belo', 'bem', 'beneficiada',
#        'benefico', 'benigno', 'boa', 'boletim', 'bolo', 'bom', 'bondade',
#        'bonito', 'brilhante', 'brincando', 'brisa', 'brutal', 'busca',
#        'cabelo', 'cachorro', 'cair', 'calma', 'caloroso', 'caminho',
#        'campeonato', 'canto', 'capotou', 'cara', 'caridade', 'caridosos',
#        'carinho', 'carro', 'carta', 'casa', 'casamento', 'casar',
#        'cativada', 'cativante', 'cautela', 'celular', 'certeza', 'certo',
#        'chamar', 'charme', 'charmoso', 'chefe', 'chegada', 'cheiro',
#        'chocado', 'chocolate', 'chá', 'cidade', 'cliente', 'colega',
#        'colegas', 'coleguismo', 'coleção', 'colocou', 'com', 'comediante',
#        'comemorar', 'comemorei', 'comi', 'comida', 'como', 'comovido',
#        'companheira', 'compartilhar', 'compatíveis', 'compatível',
#        'completa', 'completamente', 'completar', 'completei', 'comprar',
#        'conclui', 'concretizamos', 'concretizei', 'confio', 'confortável',
#        'congratulações', 'conhecer', 'conhecê', 'consegui',
#        'consentimento', 'consentir', 'consigo', 'contente', 'continua',
#        'cor', 'corações', 'corredor', 'correndo', 'correr', 'crianças',
#        'criatura', 'crime', 'crimes', 'crise', 'crocodilo', 'cuidado',
#        'cuidadoso', 'culpa', 'curso', 'curvas', 'cá', 'câncer', 'cães',
#        'da', 'dados', 'dançamos', 'daqui', 'dar', 'de', 'dedico', 'deixa',
#        'deixe', 'deixou', 'deleite', 'delicada', 'delicadamente',
#        'delicioso', 'demais', 'depois', 'depor', 'depressa',
#        'desapareceu', 'desastre', 'descoberto', 'descobrir',
#        'descobriram', 'descobrirem', 'desconfiada', 'desconhecido',
#        'desejo', 'desejável', 'desemprego', 'desgraça', 'deslumbrante',
#        'despreocupada', 'desta', 'deu', 'deus', 'dia', 'dias',
#        'dificuldades', 'difícil', 'dinheiro', 'diploma', 'direção',
#        'dirija', 'disso', 'diversão', 'divertido', 'divertiria', 'do',
#        'doce', 'doces', 'dor', 'dormir', 'dos', 'durante', 'durar',
#        'duvidas', 'dá', 'ecoou', 'ei', 'ela', 'ele', 'elefantes', 'eles',
#        'elogio', 'elogios', 'em', 'emocionado', 'emocionante', 'emprego',
#        'empresa', 'enche', 'encontrar', 'encontrei', 'enganado',
#        'engraçado', 'enorme', 'ente', 'entrego', 'entro', 'enxerguei',
#        'equipe', 'escola', 'escolhas', 'escura', 'escuridão', 'escuro',
#        'especial', 'espelho', 'espere', 'espero', 'esportivo', 'essa',
#        'esse', 'esta', 'estamos', 'estar', 'estaremos', 'este',
#        'estimados', 'estimo', 'estivemos', 'estou', 'estrada', 'estranho',
#        'estranhos', 'estrelas', 'estremecendo', 'está', 'estão', 'eu',
#        'eufórica', 'exame', 'explicar', 'extremamente', 'facilmente',
#        'faculdade', 'faminto', 'família', 'favor', 'favorito', 'faz',
#        'fazem', 'façam', 'faço', 'feliz', 'felizes', 'ferias', 'ferrados',
#        'festa', 'fica', 'ficando', 'ficar', 'ficarmos', 'fico', 'ficou',
#        'fiel', 'figura', 'filha', 'filho', 'filhos', 'filme', 'finais',
#        'finalmente', 'financeira', 'fiquei', 'fiz', 'floresta',
#        'flutuando', 'foi', 'forte', 'fortuna', 'forças', 'foto',
#        'fotografia', 'frio', 'frutas', 'fugir', 'fui', 'fuja', 'férias',
#        'ganhei', 'ganhou', 'garota', 'gol', 'gosto', 'graduação',
#        'grande', 'grata', 'graças', 'grito', 'grupo', 'guarda', 'hoje',
#        'honras', 'hora', 'humilhado', 'ideal', 'ideia', 'imensamente',
#        'imploro', 'incrível', 'indo', 'inesperada', 'inesperado',
#        'inesquecível', 'inferno', 'ingresso', 'inocente', 'inquietantes',
#        'inquieto', 'intimado', 'intimidada', 'investida', 'ir', 'irá',
#        'irão', 'isso', 'janela', 'jogo', 'jogos', 'juiz', 'julgamentos',
#        'juntos', 'juro', 'largar', 'lembro', 'levar', 'ligando',
#        'ligação', 'ligeiro', 'linda', 'lindo', 'livrar', 'livro', 'lo',
#        'lobisomem', 'loucamente', 'luar', 'lucro', 'lugar', 'lá', 'macio',
#        'mail', 'mais', 'mal', 'mantenha', 'maravilhas', 'maravilhoso',
#        'maravilhosos', 'marcou', 'mas', 'mate', 'matem', 'matou', 'me',
#        'medida', 'medo', 'meio', 'melhor', 'melhores', 'mensagem',
#        'mesada', 'mesmo', 'meu', 'meus', 'milagre', 'mim', 'minha',
#        'minhas', 'minuto', 'missão', 'misteriosa', 'misterioso',
#        'monstruosamente', 'montanha', 'montanhas', 'montro', 'mortes',
#        'mortos', 'movendo', 'mover', 'moveu', 'muita', 'muito', 'muitos',
#        'mundo', 'musica', 'música', 'na', 'nadar', 'namorando', 'naquilo',
#        'nas', 'nascer', 'nascimento', 'natal', 'natural', 'negativa',
#        'negra', 'nele', 'nem', 'nenhum', 'nervoso', 'nessa', 'neste',
#        'nestes', 'no', 'noite', 'nos', 'nossa', 'nosso', 'nota',
#        'noticia', 'notificado', 'notícia', 'notícias', 'nova',
#        'novamente', 'novas', 'novo', 'nunca', 'não', 'nós', 'número',
#        'objetivo', 'olha', 'olhar', 'olho', 'olhos', 'ordem', 'orelha',
#        'orçamento', 'os', 'outra', 'outro', 'ouvi', 'ouvindo', 'ouvir',
#        'ouço', 'paciente', 'pagar', 'pais', 'paixões', 'palmas', 'para',
#        'paranormal', 'parece', 'parede', 'parque', 'passar', 'passos',
#        'paz', 'pedir', 'pegarem', 'pela', 'pelo', 'pelos', 'pena',
#        'pensar', 'percebi', 'perde', 'perder', 'perdi', 'perdido',
#        'perfume', 'perigosa', 'perigoso', 'perigosos', 'perseguindo',
#        'perto', 'perturba', 'perturbadora', 'pesadelos', 'pessoas',
#        'pintura', 'planejadas', 'plano', 'pode', 'podemos', 'poder',
#        'poderei', 'poderemos', 'policiais', 'políticos', 'população',
#        'por', 'porão', 'possa', 'poste', 'povo', 'pra', 'praia', 'prazer',
#        'precisei', 'preciso', 'preconceitos', 'prender', 'preocupam',
#        'preocupo', 'preparativos', 'presente', 'presença', 'primeiro',
#        'projeto', 'proposta', 'provocou', 'prêmio', 'próximos',
#        'publicado', 'pude', 'puder', 'pôr', 'quando', 'quanta', 'quarto',
#        'quase', 'que', 'quem', 'quente', 'queria', 'querida', 'queridas',
#        'querido', 'quero', 'quietos', 'quis', 'radiante', 'rainha',
#        'rapaz', 'rapidamente', 'reabriu', 'reais', 'realmente', 'recebi',
#        'receio', 'reconfortada', 'reconfortante', 'recuperando', 'redes',
#        'relatos', 'relaxante', 'remedio', 'respirar', 'restaurante',
#        'resultado', 'risco', 'riscos', 'rodeada', 'roubar', 'roupa',
#        'rua', 'russa', 'ruído', 'rápido', 'sair', 'sala', 'salvem',
#        'salvo', 'salário', 'sapato', 'satisfatoriamente', 'saída',
#        'saúde', 'se', 'segredo', 'segura', 'segurança', 'seguro', 'sei',
#        'seja', 'selva', 'selvagem', 'selvagens', 'sem', 'sempre', 'sendo',
#        'sente', 'sentença', 'sentimentos', 'sentindo', 'ser', 'serei',
#        'serio', 'será', 'seu', 'seus', 'show', 'significa', 'silencioso',
#        'silêncio', 'simpático', 'sinistra', 'sinistro', 'sinto',
#        'situação', 'sobre', 'sobrinho', 'sociais', 'socorro', 'sol',
#        'soltem', 'sombra', 'sombras', 'somo', 'somos', 'sonho', 'sonhos',
#        'sorrindo', 'sorrir', 'sorteio', 'sou', 'sozinho', 'spa', 'sua',
#        'suando', 'suas', 'sucesso', 'suco', 'surpreendido', 'surpresa',
#        'suspense', 'sussurros', 'são', 'só', 'sótão', 'tamanha', 'tanto',
#        'tarde', 'tarefa', 'te', 'telefone', 'tem', 'temo', 'temor',
#        'temos', 'tempestade', 'tempo', 'tendo', 'tenham', 'tenho',
#        'tenso', 'tentar', 'ter', 'terei', 'terminada', 'terminado',
#        'terror', 'terrível', 'testes', 'texto', 'tigre', 'time', 'tirar',
#        'tire', 'tive', 'todas', 'todo', 'todos', 'tomar', 'tomara',
#        'toquei', 'trabalhador', 'trabalhar', 'trabalho', 'trabalhos',
#        'traz', 'tremendo', 'trovão', 'tubarões', 'tudo', 'tão',
#        'ultrapassa', 'um', 'uma', 'universidade', 'usam', 'vai', 'vale',
#        'vamos', 'vazia', 'vazio', 'vejam', 'vejo', 'vencedor', 'venceu',
#        'ver', 'verdade', 'verem', 'vestido', 'vi', 'viagem', 'vida',
#        'vigiando', 'vilas', 'vindo', 'vinho', 'violentos', 'vir',
#        'vitórias', 'viva', 'viver', 'vivo', 'vizinhança', 'você', 'vocês',
#        'volta', 'voltar', 'vou', 'voz', 'vulto', 'vão', 'vírus', 'água',
#        'ânimos', 'ímpeto', 'órgão', 'ótimo', 'último'], dtype=object)

# %%
vectorizer.vocabulary_
# Out:
# {'recebi': 673,
#  'um': 812,
#  'elogio': 323,
#  'do': 307,
#  'meu': 503,
#  'chefe': 197,
#  'adoro': 19,
#  'seu': 724,
#  'cabelo': 170,
#  'macio': 481,
#  'eu': 369,
#  'sou': 750,
#  'sua': 753,
#  'rainha': 667,
#  'estou': 361,
#  'feliz': 384,
#  'por': 625,
#  'ter': 782,
#  'terminado': 785,
#  'projeto': 643,
#  'este': 357,
#  'lugar': 479,
#  'continua': 240,
#  'assustador': 129,
#  'tomara': 799,
#  'que': 656,
#  'eles': 322,
#  'não': 561,
#  'me': 494,
#  'vejam': 821,
#  'daqui': 263,
#  'nascer': 533,
#  'sol': 739,
#  'nas': 532,
#  'montanhas': 515,
#  'incrível': 440,
#  'te': 769,
#  'entrego': 337,
#  'dinheiro': 299,
#  'favor': 378,
#  'mate': 491,
#  'encontrei': 332,
#  'uma': 813,
#  'nota': 551,
#  'antiga': 82,
#  'de': 265,
#  'amor': 68,
#  'fiquei': 404,
#  'emocionado': 326,
#  'desejo': 286,
#  'você': 843,
#  'tudo': 809,
#  'bom': 162,
#  'serei': 721,
#  'amiga': 62,
#  'companheira': 218,
#  'somos': 744,
#  'compatíveis': 220,
#  'com': 210,
#  'outro': 574,
#  'notícia': 554,
#  'família': 377,
#  'está': 367,
#  'vindo': 834,
#  'alegra': 45,
#  'mail': 482,
#  'ameaçador': 55,
#  'abundante': 4,
#  'animado': 74,
#  'para': 584,
#  'conhecer': 233,
#  'novas': 558,
#  'pessoas': 613,
#  'carta': 184,
#  'agradecimento': 36,
#  'inesperada': 442,
#  'na': 528,
#  'montanha': 514,
#  'deslumbrante': 290,
#  'adorei': 18,
#  'perfume': 604,
#  'tive': 794,
#  'culpa': 254,
#  'juro': 463,
#  'fui': 417,
#  'brilhante': 165,
#  'filme': 400,
#  'terror': 786,
#  'deu': 293,
#  'pesadelos': 612,
#  'noite': 547,
#  'time': 791,
#  'esportivo': 350,
#  'favorito': 379,
#  'ganhou': 421,
#  'jogo': 458,
#  'as': 120,
#  'notícias': 555,
#  'desastre': 279,
#  'natural': 536,
#  'preocupam': 637,
#  'mensagem': 500,
#  'ameaçadora': 56,
#  'no': 546,
#  'assistir': 125,
#  'engraçado': 334,
#  'deixa': 267,
#  'alegre': 46,
#  'indo': 441,
#  'finais': 401,
#  'vulto': 849,
#  'misterioso': 512,
#  'apareceu': 90,
#  'foto': 412,
#  'tempestade': 775,
#  'ficando': 390,
#  'mais': 483,
#  'forte': 409,
#  'tenho': 779,
#  'certeza': 192,
#  'se': 703,
#  'seguro': 707,
#  'vi': 829,
#  'algo': 48,
#  'sinistro': 732,
#  'canto': 177,
#  'olho': 567,
#  'nossa': 549,
#  'como': 216,
#  'afortunado': 26,
#  'ser': 720,
#  'surpreendido': 758,
#  'festa': 388,
#  'tremendo': 806,
#  'medo': 496,
#  'comemorei': 213,
#  'aniversário': 78,
#  'bolo': 161,
#  'delicioso': 273,
#  'radiante': 666,
#  'nascimento': 534,
#  'sobrinho': 736,
#  'muito': 523,
#  'grata': 427,
#  'preocupo': 638,
#  'aconteceu': 13,
#  'confio': 230,
#  'nele': 539,
#  'cautela': 190,
#  'ficar': 391,
#  'sozinho': 751,
#  'em': 325,
#  'casa': 185,
#  'vazia': 819,
#  'aceito': 7,
#  'universidade': 814,
#  'sempre': 714,
#  'quis': 665,
#  'cheiro': 199,
#  'assando': 122,
#  'enche': 330,
#  'alegria': 47,
#  'aquela': 108,
#  'abandonada': 0,
#  'sinistra': 731,
#  'ouvi': 575,
#  'barulho': 150,
#  'estranho': 363,
#  'porão': 626,
#  'vou': 847,
#  'sem': 713,
#  'mesada': 501,
#  'tirar': 792,
#  'baixa': 148,
#  'plano': 616,
#  'pode': 617,
#  'descoberto': 280,
#  'ate': 136,
#  'floresta': 406,
#  'negra': 538,
#  'perigoso': 606,
#  'marcou': 489,
#  'gol': 423,
#  'último': 857,
#  'minuto': 509,
#  'surpresa': 759,
#  'correndo': 244,
#  'riscos': 686,
#  'saúde': 702,
#  'abominável': 1,
#  'esse': 352,
#  'montro': 516,
#  'abraço': 2,
#  'caloroso': 174,
#  'amigo': 63,
#  'calma': 173,
#  'isso': 456,
#  'remedio': 681,
#  'matem': 492,
#  'sussurros': 761,
#  'inquietantes': 448,
#  'corredor': 243,
#  'novo': 559,
#  'vírus': 851,
#  'são': 762,
#  'aterrorizantes': 139,
#  'livro': 473,
#  'foi': 408,
#  'adaptado': 14,
#  'consegui': 235,
#  'emprego': 328,
#  'salário': 698,
#  'concretizamos': 228,
#  'ideia': 437,
#  'contente': 239,
#  'passar': 589,
#  'tempo': 776,
#  'meus': 504,
#  'avós': 146,
#  'estamos': 354,
#  'felizes': 385,
#  'juntos': 462,
#  'crime': 248,
#  'minha': 507,
#  'vizinhança': 842,
#  'perturbadora': 611,
#  'proposta': 644,
#  'dos': 312,
#  'sonhos': 746,
#  'deixou': 269,
#  'crianças': 246,
#  'brincando': 166,
#  'parque': 588,
#  'fazem': 381,
#  'sorrir': 748,
#  'figura': 396,
#  'assustadora': 130,
#  'dor': 310,
#  'esta': 353,
#  'amenizando': 61,
#  'finalmente': 402,
#  'roupa': 689,
#  'delicada': 271,
#  'ganhei': 420,
#  'prêmio': 646,
#  'fotografia': 413,
#  'graças': 428,
#  'deus': 294,
#  'enxerguei': 339,
#  'certo': 193,
#  'admirada': 17,
#  'muitos': 524,
#  'temo': 772,
#  'pela': 594,
#  'segurança': 706,
#  'ruído': 692,
#  'meio': 497,
#  'da': 260,
#  'perturba': 610,
#  'escuridão': 344,
#  'apreensivo': 101,
#  'queridas': 661,
#  'ver': 825,
#  'filho': 398,
#  'sorrindo': 747,
#  'ligação': 468,
#  'misteriosa': 511,
#  'depois': 275,
#  'sótão': 764,
#  'sinto': 733,
#  'viva': 839,
#  'afugente': 29,
#  'os': 572,
#  'cães': 259,
#  'afogar': 25,
#  'ajudem': 42,
#  'sair': 694,
#  'água': 852,
#  'poderemos': 621,
#  'completar': 224,
#  'hoje': 432,
#  'apavorando': 94,
#  'ansiosa': 80,
#  'chegada': 198,
#  'ótimo': 856,
#  'compatível': 221,
#  'sonho': 745,
#  'doce': 308,
#  'aprovada': 103,
#  'exame': 371,
#  'namorando': 530,
#  'vestido': 828,
#  'janela': 457,
#  'dá': 316,
#  'arrepios': 115,
#  'espelho': 347,
#  'banheiro': 149,
#  'ao': 85,
#  'pôr': 651,
#  'praia': 631,
#  'cara': 179,
#  'perseguindo': 608,
#  'dificuldades': 297,
#  'respirar': 682,
#  'assustado': 128,
#  'ele': 320,
#  'realmente': 672,
#  'fiel': 395,
#  'mim': 506,
#  'órgão': 855,
#  'paciente': 579,
#  'silencioso': 728,
#  'cuidado': 252,
#  'consentimento': 236,
#  'pais': 581,
#  'podemos': 618,
#  'nos': 548,
#  'casar': 187,
#  'pude': 649,
#  'comprar': 226,
#  'celular': 191,
#  'mover': 520,
#  'assustou': 134,
#  'socorro': 738,
#  'queria': 659,
#  'roubar': 688,
#  'doces': 309,
#  'desconfiada': 284,
#  'ameaça': 54,
#  'redes': 678,
#  'sociais': 737,
#  'presente': 640,
#  'especial': 346,
#  'nunca': 560,
#  'duvidas': 315,
#  'ouvindo': 576,
#  'passos': 590,
#  'atrás': 144,
#  'completamente': 223,
#  'apaixonada': 86,
#  'aproveitando': 104,
#  'ferias': 386,
#  'moveu': 521,
#  'armário': 114,
#  'parece': 586,
#  'tem': 771,
#  'olhos': 568,
#  'vigiando': 832,
#  'percebi': 599,
#  'sombras': 742,
#  'movendo': 519,
#  'sala': 695,
#  'estar': 355,
#  'quente': 658,
#  'neste': 544,
#  'frio': 414,
#  'soltem': 740,
#  'inocente': 447,
#  'dia': 295,
#  'spa': 752,
#  'elogios': 324,
#  'pelo': 595,
#  'trabalho': 803,
#  'desejável': 287,
#  'presença': 641,
#  'apresentação': 102,
#  'sobre': 735,
#  'desconhecido': 285,
#  'assustadoras': 131,
#  'comida': 215,
#  'atraente': 141,
#  'número': 563,
#  'arrumação': 119,
#  'terminada': 784,
#  'alívio': 51,
#  'aproximando': 106,
#  'rapidamente': 669,
#  'tire': 793,
#  'advertiram': 23,
#  'restaurante': 683,
#  'reabriu': 670,
#  'aterrorizante': 138,
#  'assombrado': 126,
#  'crise': 250,
#  'financeira': 403,
#  'agradeço': 37,
#  'imensamente': 438,
#  'apoio': 98,
#  'nestes': 545,
#  'dias': 296,
#  'relatos': 679,
#  'atividade': 140,
#  'paranormal': 585,
#  'assustadores': 132,
#  'chá': 202,
#  'reconfortante': 676,
#  'sombra': 741,
#  'parede': 587,
#  'espere': 348,
#  'largar': 464,
#  'aqui': 110,
#  'bem': 155,
#  'ordem': 569,
#  'agora': 33,
#  'olha': 565,
#  'criatura': 247,
#  'monstruosamente': 513,
#  'tenso': 780,
#  'nervoso': 542,
#  'benefico': 157,
#  'todos': 797,
#  'nova': 556,
#  'medida': 495,
#  'apavorada': 92,
#  'ansioso': 81,
#  'encontrar': 331,
#  'crimes': 249,
#  'violentos': 836,
#  'concretizei': 229,
#  'grito': 429,
#  'ecoou': 317,
#  'silêncio': 729,
#  'tubarões': 808,
#  'estão': 368,
#  'atacando': 135,
#  'amigos': 64,
#  'estremecendo': 366,
#  'essa': 351,
#  'russa': 691,
#  'sente': 716,
#  'humilhado': 435,
#  'apavorado': 93,
#  'estranhos': 364,
#  'emocionante': 327,
#  'temos': 774,
#  'abundancia': 3,
#  'suco': 757,
#  'inesquecível': 444,
#  'alguem': 49,
#  'ligando': 467,
#  'ouvir': 577,
#  'assusta': 127,
#  'flutuando': 407,
#  'ar': 111,
#  'trabalhador': 801,
#  'temor': 773,
#  'desemprego': 288,
#  'apavora': 91,
#  'advertida': 21,
#  'novamente': 557,
#  'texto': 789,
#  'adorável': 20,
#  'congratulações': 232,
#  'inquieto': 449,
#  'saída': 701,
#  'preciso': 634,
#  'milagre': 505,
#  'ameaçando': 57,
#  'férias': 419,
#  'planejadas': 615,
#  'sei': 708,
#  'nadar': 529,
#  'fiz': 405,
#  'adesão': 16,
#  'curso': 255,
#  'ações': 147,
#  'colega': 205,
#  'sorteio': 749,
#  'bondade': 163,
#  'vir': 837,
#  'ficou': 394,
#  'lindo': 471,
#  'musica': 526,
#  'linda': 470,
#  'viagem': 830,
#  'acho': 10,
#  'sendo': 715,
#  'enganado': 333,
#  'tanto': 766,
#  'vamos': 818,
#  'caridosos': 181,
#  'natal': 535,
#  'bela': 153,
#  'grande': 426,
#  'alivio': 50,
#  'divertido': 305,
#  'dedico': 266,
#  'naquilo': 531,
#  'faço': 383,
#  'minhas': 508,
#  'paixões': 582,
#  'escuro': 345,
#  'intimado': 450,
#  'depor': 276,
#  'bonito': 164,
#  'deleite': 270,
#  'poder': 619,
#  'compartilhar': 219,
#  'vitórias': 838,
#  'maravilhoso': 487,
#  'cativante': 189,
#  'quero': 663,
#  'nem': 540,
#  'pensar': 598,
#  'acontecer': 12,
#  'ouço': 578,
#  'direção': 301,
#  'amar': 53,
#  'voz': 848,
#  'completei': 225,
#  'coleção': 208,
#  'melhor': 498,
#  'chamar': 194,
#  'comemorar': 212,
#  'comovido': 217,
#  'tamanha': 765,
#  'caridade': 180,
#  'descobriram': 282,
#  'irão': 455,
#  'prender': 636,
#  'selva': 710,
#  'animais': 76,
#  'perigosos': 607,
#  'escura': 343,
#  'conclui': 227,
#  'graduação': 425,
#  'sucesso': 756,
#  'angustiada': 71,
#  'vivo': 841,
#  'políticos': 623,
#  'usam': 815,
#  'suas': 755,
#  'forças': 411,
#  'afugentar': 28,
#  'amedrontar': 60,
#  'povo': 629,
#  'muita': 522,
#  'aterrorizado': 137,
#  'suando': 754,
#  'brisa': 167,
#  'agradável': 38,
#  'vazio': 820,
#  'vocês': 844,
#  'terrível': 787,
#  'tigre': 790,
#  'quase': 655,
#  'matou': 493,
#  'loucamente': 476,
#  'correr': 245,
#  'pra': 630,
#  'pegarem': 593,
#  'entro': 338,
#  'lá': 480,
#  'trovão': 807,
#  'afugenta': 27,
#  'ímpeto': 854,
#  'inferno': 445,
#  'fuja': 418,
#  'faminto': 376,
#  'grupo': 430,
#  'elefantes': 321,
#  'selvagens': 712,
#  'vilas': 833,
#  'será': 723,
#  'amado': 52,
#  'mantenha': 485,
#  'segredo': 704,
#  'descobrirem': 283,
#  'estaremos': 356,
#  'ferrados': 387,
#  'voltar': 846,
#  'quando': 652,
#  'fico': 393,
#  'recuperando': 677,
#  'amo': 67,
#  'arrumar': 118,
#  'orelha': 570,
#  'vai': 816,
#  'levar': 466,
#  'todo': 796,
#  'rodeada': 687,
#  'paz': 591,
#  'cachorro': 171,
#  'diploma': 300,
#  'honras': 433,
#  'agir': 31,
#  'preconceitos': 635,
#  'julgamentos': 461,
#  'amizade': 66,
#  'durar': 314,
#  'prazer': 632,
#  'conhecê': 234,
#  'lo': 474,
#  'palmas': 583,
#  'aniversariante': 77,
#  'apanhar': 89,
#  'verem': 827,
#  'boletim': 160,
#  'eufórica': 370,
#  'noticia': 552,
#  'mal': 484,
#  'tão': 810,
#  'animada': 73,
#  'preparativos': 639,
#  'casamento': 186,
#  'agradar': 34,
#  'filhos': 399,
#  'melhores': 499,
#  'sentença': 717,
#  'juiz': 460,
#  'possa': 627,
#  'negativa': 537,
#  'escolhas': 342,
#  'todas': 795,
#  'pintura': 614,
#  'coleguismo': 207,
#  'animador': 75,
#  'querida': 660,
#  'pelos': 596,
#  'somo': 743,
#  'amáveis': 69,
#  'perto': 609,
#  'mesmo': 502,
#  'lembro': 465,
#  'publicado': 648,
#  'câncer': 258,
#  'benigno': 158,
#  'armado': 113,
#  'gosto': 424,
#  'aconchego': 11,
#  'intimidada': 451,
#  'notificado': 553,
#  'perde': 600,
#  'guarda': 431,
#  'filha': 397,
#  'objetivo': 564,
#  'disso': 303,
#  'apenas': 96,
#  'amistoso': 65,
#  'serio': 722,
#  'arma': 112,
#  'mas': 490,
#  'missão': 510,
#  'arriscada': 116,
#  'população': 624,
#  'provocou': 645,
#  'mortes': 517,
#  'satisfatoriamente': 700,
#  'anuncio': 83,
#  'vencedor': 823,
#  'jogos': 459,
#  'cair': 172,
#  'perigosa': 605,
#  'deixe': 268,
#  'viver': 840,
#  'angustiadamente': 72,
#  'tendo': 777,
#  'lucro': 478,
#  'nessa': 543,
#  'cidade': 203,
#  'desgraça': 289,
#  'outra': 573,
#  'aquele': 109,
#  'rapaz': 668,
#  'extremamente': 373,
#  'ligeiro': 469,
#  'fugir': 416,
#  'depressa': 277,
#  'tarde': 767,
#  'poderei': 620,
#  'assaltada': 121,
#  'maravilhas': 486,
#  'mundo': 525,
#  'beneficiada': 156,
#  'empresa': 329,
#  'aproveitar': 105,
#  'chocado': 200,
#  'amedrontado': 59,
#  'assassinato': 123,
#  'brutal': 168,
#  'só': 763,
#  'espero': 349,
#  'façam': 382,
#  'nenhum': 541,
#  'resultado': 684,
#  'testes': 788,
#  'achei': 9,
#  'sapato': 699,
#  'simpático': 730,
#  'divertiria': 306,
#  'assim': 124,
#  'inesperado': 443,
#  'colocou': 209,
#  'primeiro': 642,
#  'tarefa': 768,
#  'difícil': 298,
#  'perder': 601,
#  'investida': 452,
#  'delicadamente': 272,
#  'dormir': 311,
#  'aplaudir': 97,
#  'consentir': 237,
#  'orçamento': 571,
#  'cliente': 204,
#  'charmoso': 196,
#  'querido': 662,
#  'nós': 562,
#  'dançamos': 262,
#  'adentro': 15,
#  'dar': 264,
#  'afeição': 24,
#  'amedrontada': 58,
#  'afundando': 30,
#  'música': 527,
#  'faz': 380,
#  'curvas': 256,
#  'estrada': 362,
#  'receio': 674,
#  'livrar': 472,
#  'desta': 292,
#  'situação': 734,
#  'carinho': 182,
#  'colegas': 206,
#  'agüento': 39,
#  'suspense': 760,
#  'aprecio': 100,
#  'escola': 341,
#  'risco': 685,
#  'advertido': 22,
#  'salvem': 696,
#  'quem': 657,
#  'puder': 650,
#  'acabaremos': 5,
#  'mortos': 518,
#  'venceu': 824,
#  'campeonato': 176,
#  'reais': 671,
#  'imploro': 439,
#  'quarto': 654,
#  'trabalhar': 802,
#  'equipe': 340,
#  'terei': 783,
#  'ir': 453,
#  'avancem': 145,
#  'ânimos': 853,
#  'tenham': 778,
#  'apaziguado': 95,
#  'toquei': 800,
#  'corações': 242,
#  'durante': 313,
#  'caminho': 175,
#  'pedir': 592,
#  'despreocupada': 291,
#  'aproximou': 107,
#  'beco': 152,
#  'anseio': 79,
#  'seus': 725,
#  'próximos': 647,
#  'trabalhos': 804,
#  'comi': 214,
#  'chocolate': 201,
#  'nosso': 550,
#  'ideal': 436,
#  'alcançado': 44,
#  'apaixonados': 87,
#  'maravilhosos': 488,
#  'estimados': 358,
#  'sentindo': 719,
#  'reconfortada': 675,
#  'ela': 319,
#  'boa': 159,
#  'garota': 422,
#  'ficarmos': 392,
#  'quietos': 664,
#  'vão': 850,
#  'achar': 8,
#  'cativada': 188,
#  'olhar': 566,
#  'alarmar': 43,
#  'perdido': 603,
#  'busca': 169,
#  'agradecida': 35,
#  'ajuda': 41,
#  'estivemos': 360,
#  'show': 726,
#  'apaixonei': 88,
#  'perdi': 602,
#  'dados': 261,
#  'confortável': 231,
#  'aceita': 6,
#  'faculdade': 375,
#  'agitar': 32,
#  'dirija': 302,
#  'rápido': 693,
#  'diversão': 304,
#  'ajeitar': 40,
#  'fica': 389,
#  'rua': 690,
#  'vejo': 822,
#  'estrelas': 365,
#  'charme': 195,
#  'irá': 454,
#  'atrair': 143,
#  'seja': 709,
#  'cuidadoso': 253,
#  'sentimentos': 718,
#  'comediante': 211,
#  'enorme': 335,
#  'desapareceu': 278,
#  'frutas': 415,
#  'crocodilo': 251,
#  'selvagem': 711,
#  'cá': 257,
#  'tomar': 798,
#  'lobisomem': 475,
#  'salvo': 697,
#  'consigo': 238,
#  'ei': 318,
#  'bater': 151,
#  'poste': 628,
#  'hora': 434,
#  'apreciar': 99,
#  'vinho': 835,
#  'descobrir': 281,
#  'verdade': 826,
#  'cor': 241,
#  'ente': 336,
#  'completa': 222,
#  'estimo': 359,
#  'anônima': 84,
#  'telefone': 770,
#  'demais': 274,
#  'relaxante': 680,
#  'vale': 817,
#  'pena': 597,
#  'tentar': 781,
#  'explicar': 372,
#  'segura': 705,
#  'traz': 805,
#  'volta': 845,
#  'vida': 831,
#  'arriscado': 117,
#  'quanta': 653,
#  'angustia': 70,
#  'fortuna': 410,
#  'ultrapassa': 811,
#  'significa': 727,
#  'policiais': 622,
#  'assustaram': 133,
#  'carro': 183,
#  'capotou': 178,
#  'atrai': 142,
#  'facilmente': 374,
#  'precisei': 633,
#  'pagar': 580,
#  'ingresso': 446,
#  'luar': 477,
#  'belo': 154}

# %%
frases_transformadas_treino = vectorizer.transform(frases_treino['frase'].values)
frases_transformadas_teste = vectorizer.transform(frases_teste['frase'].values)

# %%
frases_transformadas_treino
# Out:
# <510x858 sparse matrix of type '<class 'numpy.int64'>'
# 	with 1881 stored elements in Compressed Sparse Row format>

# %%
frases_transformadas_treino.shape
# Out:
# (510, 858)

# %%
frases_transformadas_teste.shape
# Out:
# (170, 858)

# %% [markdown]
# # Somente agora entra a parte de Inteligência Artificial (Aprendizado de Máquina) - Vamos Usar 2 modelos de Algoritmos diferentes para comparar o desempenho

# %% [markdown]
# ## Modelo DecisionTreeClassifier

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.metrics import ConfusionMatrixDisplay
from sklearn import metrics

# %%
arvore = DecisionTreeClassifier(max_depth=6, criterion='gini')
arvore.fit(frases_transformadas_treino,senti_treino) # aqui estou ensinando para a Máquina
y_pred_arvore = arvore.predict(frases_transformadas_teste) # aqui eu não mostro o sentimento porque ele vai ter que advinhar
score_arvore = arvore.score(frases_transformadas_teste, senti_teste) #ver o percentual de acerto
print(score_arvore)
confusion_matrix(senti_teste,y_pred_arvore)
# Out:
# 0.6941176470588235
# array([[94,  0],
#        [52, 24]])

# %%
report=classification_report(y_true=senti_teste,y_pred=y_pred_arvore)
print(report) #Mostra as métricas de resultado do modelo
# Out:
#               precision    recall  f1-score   support
#
#      alegria       0.64      1.00      0.78        94
#         medo       1.00      0.32      0.48        76
#
#     accuracy                           0.69       170
#    macro avg       0.82      0.66      0.63       170
# weighted avg       0.80      0.69      0.65       170

# %%
import matplotlib as plt

# %%
ConfusionMatrixDisplay.from_estimator(arvore, frases_transformadas_teste,senti_teste, cmap=plt.cm.Reds,normalize='true')

# %% [markdown]
# ### Testando com frases aleatórias criadas por vocês, que não estavam na base

# %%
#frase_nova = ['Fiquei muito feliz em saber deste novo curso oferecido na Etec']
#frase_nova = ['Eu me sinto péssimo quando você não vem']
frase_nova = ['Eu adorei este presente']
#frase_nova = ['Socorro estou sendo assaltado']
#frase_nova =['estou sentindo arrepios de medo acho que vi um fantasma']
#frase_nova = ['Nossa estou muito feliz porque acabei de chegar em casa e vou jogar video game']
# convertendo a frase em números
frase_nova_convertida = vectorizer.transform(frase_nova)
y_pred_arvore_unica = arvore.predict(frase_nova_convertida) # aqui eu coloco para o modelo advinhar a nova frase
y_pred_arvore_unica
# Out:
# array(['alegria'], dtype=object)

# %%
percentual_acerto = arvore.predict_proba(frase_nova_convertida)
percentual_acerto
# Out:
# array([[0.63614458, 0.36385542]])

# %% [markdown]
# ## Modelo GradientBoostingClassifier

# %%
xgb = GradientBoostingClassifier(n_estimators=3000,min_samples_leaf = 4, learning_rate=0.1, verbose=True) #Aqui configuramos o estimador
xgb.fit(frases_transformadas_treino,senti_treino) #Iniciamos o treinamento
y_pred_xgb = arvore.predict(frases_transformadas_teste) # aqui eu não mostro o sentimento porque ele vai ter que advinhar
score_xgb = arvore.score(frases_transformadas_teste, senti_teste) #ver o percentual de acerto
print(score_xgb)
confusion_matrix(senti_teste,y_pred_xgb)
# Out:
#       Iter       Train Loss   Remaining Time
#          1           1.3598           12.83s
#          2           1.3331           12.74s
#          3           1.3143           16.03s
#          4           1.2966           19.47s
#          5           1.2798           21.72s
#          6           1.2639           22.08s
#          7           1.2490           20.73s
#          8           1.2348           19.64s
#          9           1.2213           19.10s
#         10           1.2094           18.54s
#         20           1.1042           14.30s
#         30           1.0271           12.74s
#         40           0.9667           11.91s
#         50           0.9128           11.32s
#         60           0.8686           11.12s
#         70           0.8309           10.84s
#         80           0.7967           10.59s
#         90           0.7660           10.49s
#        100           0.7403           10.49s
#        200           0.5756           10.27s
#        300           0.4960           10.09s
#        400           0.4559            9.62s
#        500           0.4321            9.05s
#        600           0.4164            8.59s
#        700           0.4058            8.19s
#        800           0.3987            7.37s
#        900           0.3939            6.69s
#       1000           0.3906            6.16s
#       2000           0.3827            2.44s
#       3000           0.3824            0.00s
# 0.6941176470588235
# array([[94,  0],
#        [52, 24]])

# %%
report=classification_report(y_true=senti_teste,y_pred=y_pred_xgb)
print(report) #Mostra as métricas de resultado do modelo
# Out:
#               precision    recall  f1-score   support
#
#      alegria       0.64      1.00      0.78        94
#         medo       1.00      0.32      0.48        76
#
#     accuracy                           0.69       170
#    macro avg       0.82      0.66      0.63       170
# weighted avg       0.80      0.69      0.65       170

# %%
ConfusionMatrixDisplay.from_estimator(xgb, frases_transformadas_teste,senti_teste, cmap=plt.cm.Reds,normalize='true')

# %% [markdown]
# ### Testando com frases aleatórias criadas por vocês, que não estavam na base

# %%
#frase_nova = ['Fiquei muito feliz em saber deste novo curso oferecido na Etec']
#frase_nova = ['Socorro estou sendo assaltado']
#frase_nova =['estou sentindo arrepios de medo acho que vi um fantasma']
#frase_nova = ['Nossa estou muito feliz porque acabei de chegar em casa e vou jogar video game']
frase_nova = ['Eu me sinto péssimo quando você não vem']
# convertendo a frase em números
frase_nova_convertida = vectorizer.transform(frase_nova)
y_pred_xgb_unica = xgb.predict(frase_nova_convertida) # aqui eu coloco para o modelo advinhar a nova frase
y_pred_xgb_unica
# Out:
# array(['alegria'], dtype=object)

# %%
percentual_acerto = arvore.predict_proba(frase_nova_convertida)
percentual_acerto
# Out:
# array([[0.63614458, 0.36385542]])

# %% [markdown]
# ## SGDC

# %%
from sklearn.linear_model import SGDClassifier
from sklearn.calibration import CalibratedClassifierCV

# %%
sgdc = SGDClassifier(max_iter=3000, tol=1e-3, n_iter_no_change = 20, eta0=0.4, learning_rate = 'adaptive')
sgdc.fit(frases_transformadas_treino,senti_treino) #treinamento
calibrator = CalibratedClassifierCV(sgdc, cv='prefit') #Calibração para prever o percentual futuramente
model_sgdc = calibrator.fit(frases_transformadas_treino,senti_treino) #treinamento com a calibração
y_pred_sgd = model_sgdc.predict(frases_transformadas_teste) # previsões com a nova base
score_sgd = model_sgdc.score(frases_transformadas_teste, senti_teste) #percentual de acerto do modelo com a base de teste
print(score_sgd)
confusion_matrix(senti_teste,y_pred_sgd) #Gera a matriz de confusão

# %%
report=classification_report(y_true=senti_teste,y_pred=y_pred_sgd)
print(report) #Mostra as métricas de resultado do modelo

# %%
plot_confusion_matrix(model_sgdc, frases_transformadas_teste,senti_teste, cmap=plt.cm.Reds,normalize='true')

# %% [markdown]
# ### Testando com frases aleatórias criadas por vocês, que não estavam na base

# %%
#frase_nova = ['Fiquei muito feliz em saber deste novo curso oferecido na Etec']
frase_nova = ['Socorro estou sendo assaltado']
#frase_nova =['estou sentindo arrepios de medo acho que vi um fantasma']
#frase_nova = ['Nossa estou muito feliz porque acabei de chegar em casa e vou jogar video game']
# convertendo a frase em números
frase_nova_convertida = vectorizer.transform(frase_nova)
y_pred_sgdc_unica = model_sgdc.predict(frase_nova_convertida) # aqui eu coloco para o modelo advinhar a nova frase
y_pred_sgdc_unica

# %%
percentual_acerto = model_sgdc.predict_proba(frase_nova_convertida)
percentual_acerto
